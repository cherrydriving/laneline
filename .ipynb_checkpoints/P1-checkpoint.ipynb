# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
#
# ## Project: **Finding Lane Lines on the Road**
# ***
# In this project, you will use the tools you learned about in the lesson to identify lane lines on the road.  You can develop your pipeline on a series of individual images, and later apply the result to a video stream (really just a series of images). Check out the video clip "raw-lines-example.mp4" (also contained in this repository) to see what the output should look like after using the helper functions below.
#
# Once you have a result that looks roughly like "raw-lines-example.mp4", you'll need to get creative and try to average and/or extrapolate the line segments you've detected to map out the full extent of the lane lines.  You can see an example of the result you're going for in the video "P1_example.mp4".  Ultimately, you would like to draw just one line for the left side of the lane, and one for the right.
#
# In addition to implementing code, there is a brief writeup to complete. The writeup should be completed in a separate file, which can be either a markdown file or a pdf document. There is a [write up template](https://github.com/udacity/CarND-LaneLines-P1/blob/master/writeup_template.md) that can be used to guide the writing process. Completing both the code in the Ipython notebook and the writeup template will cover all of the [rubric points](https://review.udacity.com/#!/rubrics/322/view) for this project.
#
# ---
# Let's have a look at our first image called 'test_images/solidWhiteRight.jpg'.  Run the 2 cells below (hit Shift-Enter or the "play" button above) to display the image.
#
# **Note: If, at any point, you encounter frozen display windows or other confounding issues, you can always start again with a clean slate by going to the "Kernel" menu above and selecting "Restart & Clear Output".**
#
# ---

# %% [markdown]
# **The tools you have are color selection, region of interest selection, grayscaling, Gaussian smoothing, Canny Edge Detection and Hough Tranform line detection.  You  are also free to explore and try other techniques that were not presented in the lesson.  Your goal is piece together a pipeline to detect the line segments in the image, then average/extrapolate them and draw them onto the image for display (as below).  Once you have a working pipeline, try it out on the video stream below.**
#
# ---
#
# <figure>
#  <img src="examples/line-segments-example.jpg" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your output should look something like this (above) after detecting line segments using the helper functions below </p>
#  </figcaption>
# </figure>
#  <p></p>
# <figure>
#  <img src="examples/laneLines_thirdPass.jpg" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your goal is to connect/average/extrapolate line segments to get output like this</p>
#  </figcaption>
# </figure>

# %% [markdown]
# **Run the cell below to import some packages.  If you get an `import error` for a package you've already installed, try changing your kernel (select the Kernel menu above --> Change Kernel).  Still have problems?  Try relaunching Jupyter Notebook from the terminal prompt.  Also, see [this forum post](https://carnd-forums.udacity.com/cq/viewquestion.action?spaceKey=CAR&id=29496372&questionTitle=finding-lanes---import-cv2-fails-even-though-python-in-the-terminal-window-has-no-problem-with-import-cv2) for more troubleshooting tips.**

# %% [markdown]
# ## Import Packages

# %%
#importing some useful packages
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
# %matplotlib inline

# %% [markdown]
# ## Read in an Image

# %%
def read_image(image_path):
    return mpimg.imread(image_path)

def print_image_dims(image):
    print('This image is:', type(image), 'with dimensions:', image.shape)
    plt.imshow(image)
    return image

test_images = [read_image('test_images/' + i) for i in os.listdir('test_images/')]

#reading in an image
image = test_images[0]
print_image_dims(image)
# Out:
# This image is: <class 'numpy.ndarray'> with dimensions: (540, 960, 3)
# array([[[109, 158, 199],
#         [109, 158, 199],
#         [109, 158, 199],
#         ...,
#         [111, 156, 197],
#         [108, 153, 194],
#         [103, 148, 189]],
#
#        [[109, 158, 199],
#         [109, 158, 199],
#         [109, 158, 199],
#         ...,
#         [111, 156, 197],
#         [108, 153, 194],
#         [104, 149, 190]],
#
#        [[109, 158, 199],
#         [109, 158, 199],
#         [109, 158, 199],
#         ...,
#         [111, 156, 197],
#         [108, 153, 194],
#         [104, 149, 190]],
#
#        ...,
#        [[ 85,  88,  95],
#         [ 85,  88,  95],
#         [ 85,  88,  95],
#         ...,
#         [ 81,  81,  91],
#         [ 80,  80,  90],
#         [ 79,  79,  89]],
#
#        [[ 86,  86,  94],
#         [ 86,  86,  94],
#         [ 87,  87,  95],
#         ...,
#         [ 77,  80,  89],
#         [ 77,  80,  89],
#         [ 76,  79,  88]],
#
#        [[ 84,  84,  92],
#         [ 84,  84,  92],
#         [ 84,  84,  92],
#         ...,
#         [ 76,  78,  90],
#         [ 75,  77,  89],
#         [ 74,  76,  88]]], dtype=uint8)

# %% [markdown]
# ## Ideas for Lane Detection Pipeline

# %% [markdown]
# **Some OpenCV functions (beyond those introduced in the lesson) that might be useful for this project are:**
#
# `cv2.inRange()` for color selection
# `cv2.fillPoly()` for regions selection
# `cv2.line()` to draw lines on an image given endpoints
# `cv2.addWeighted()` to coadd / overlay two images
# `cv2.cvtColor()` to grayscale or change color
# `cv2.imwrite()` to output images to file
# `cv2.bitwise_and()` to apply a mask to an image
#
# **Check out the OpenCV documentation to learn about these and discover even more awesome functionality!**

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# Below are some helper functions to help get you started. They should look familiar from the lesson!

# %%
import math

def grayscale(img):
    """Applies the Grayscale transform
    This will return an image with only one color channel
    but NOTE: to see the returned image as grayscale
    (assuming your grayscaled image is called 'gray')
    you should call plt.imshow(gray, cmap='gray')"""
    return cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    # Or use BGR2GRAY if you read an image with cv2.imread()
    # return cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
def canny(img, low_threshold, high_threshold):
    """Applies the Canny transform"""
    return cv2.Canny(img, low_threshold, high_threshold)

def gaussian_blur(img, kernel_size):
    """Applies a Gaussian Noise kernel"""
    return cv2.GaussianBlur(img, (kernel_size, kernel_size), 0)

def region_of_interest(img, vertices):
    """
    Applies an image mask.
    
    Only keeps the region of the image defined by the polygon
    formed from `vertices`. The rest of the image is set to black.
    """
    #defining a blank mask to start with
    mask = np.zeros_like(img)   
    
    #defining a 3 channel or 1 channel color to fill the mask with depending on the input image
    if len(img.shape) > 2:
        channel_count = img.shape[2]  # i.e. 3 or 4 depending on your image
        ignore_mask_color = (255,) * channel_count
    else:
        ignore_mask_color = 255
        
    #filling pixels inside the polygon defined by "vertices" with the fill color    
    cv2.fillPoly(mask, vertices, ignore_mask_color)
    
    #returning the image only where mask pixels are nonzero
    masked_image = cv2.bitwise_and(img, mask)
    return masked_image

def get_line_parameter(slope_array):
    kept_slopes = []
    kept_intercepts = []
    if len(slope_array) == 1:
        return slope_array[0][0], slope_array[0][1]

    # Remove points with slope not within 1.5 standard deviations of the mean
    slopes = [pair[0] for pair in slope_array]
    slope_mean = np.mean(slopes)
    slope_std = np.std(slopes)
    for pair in slope_array:
        slope = pair[0]
        if slope - slope_mean < 1.5 * slope_std:
            kept_slopes.append(slope)
            kept_intercepts.append(pair[1])
    if not kept_slopes:
        kept_slopes = slopes
        kept_intercepts = [pair[1] for pair in slope_array]
    # Take estimate of slope, intercept to be the mean of remaining values
    slope = np.mean(kept_slopes)
    intercept = np.mean(kept_intercepts)
    return slope, intercept

def draw_linear_line(coef, intercept, intersection_x, img, imshape=[540,960], color=[255, 0, 0], thickness=2):
    print("Coef: ", coef, "Intercept: ", intercept, 
          "intersection_x: ", intersection_x)

    if coef > 0:
        intersection_x_adjusted = intersection_x + 5
        point_one = (int(intersection_x_adjusted), int(intersection_x_adjusted * coef + intercept))
        point_two = (imshape[1], int(imshape[1] * coef + intercept))
    elif coef < 0:
        intersection_x_adjusted = intersection_x - 5
        point_one = (int(intersection_x_adjusted), int(intersection_x_adjusted * coef + intercept))
        point_two = (0, int(0 * coef + intercept))
    print("Point one: ", point_one, "Point two: ", point_two)
    
    # Draw line using cv2.line
    cv2.line(img, point_one, point_two, color, thickness)
    
def draw_lines(img, lines, color=[255, 0, 0], thickness=2):
    """
    NOTE: this is the function you might want to use as a starting point once you want to 
    average/extrapolate the line segments you detect to map out the full
    extent of the lane (going from the result shown in raw-lines-example.mp4
    to that shown in P1_example.mp4).  
    
    Think about things like separating line segments by their 
    slope ((y2-y1)/(x2-x1)) to decide which segments are part of the left
    line vs. the right line.  Then, you can average the position of each of 
    the lines and extrapolate to the top and bottom of the lane.
    
    This function draws `lines` with `color` and `thickness`.    
    Lines are drawn on the image inplace (mutates the image).
    If you want to make the lines semi-transparent, think about combining
    this function with the weighted_img() function below
    """
    # Image parameters
    imshape = [540, 960]
    
    # Initialise arrays
    left_slope = []
    right_slope = []
    
    for line in lines:
        for x1,y1,x2,y2 in line:            
            slope = (y1-y2)/(x1-x2)
            length = math.sqrt((x1-x2)**2 + (y1-y2)**2)
            if not math.isnan(slope):
                if length > 50:
                    if slope > 0:
                        left_slope.append([slope, y1-slope*x1])
                    elif slope < 0:
                        right_slope.append([slope, y1-slope*x1])
        
    if not left_slope:
        for line in lines:
            for x1,y1,x2,y2 in line:            
                slope = (y1-y2)/(x1-x2)
                if slope > 0:
                    left_slope.append([slope, y1-slope*x1])
    if not right_slope:
        for line in lines:
            for x1,y1,x2,y2 in line:            
                slope = (y1-y2)/(x1-x2)
                if slope < 0:
                    right_slope.append([slope, y1-slope*x1])
    if not left_slope:
        print("left_slope is empty")
    if not right_slope:
        print("right_slope is empty")    

    # Get intercept and coefficient of fitted lines
    left_coefficient, left_intercept = get_line_parameter(left_slope)
    right_coefficient, right_intercept = get_line_parameter(right_slope)

    # Get intersection point
    intersection_x = (right_intercept-left_intercept)/(left_coefficient-right_coefficient)
    
    # Plot lines
    draw_linear_line(left_coefficient, left_intercept, intersection_x, img)
    draw_linear_line(right_coefficient, right_intercept, intersection_x, img)

def hough_lines(img, rho, theta, threshold, min_line_len, max_line_gap):
    """
    `img` should be the output of a Canny transform.
        
    Returns an image with hough lines drawn.
    """
    lines = cv2.HoughLinesP(img, rho, theta, threshold, np.array([]), minLineLength=min_line_len, maxLineGap=max_line_gap)
    line_img = np.zeros((img.shape[0], img.shape[1], 3), dtype=np.uint8)
    draw_lines(line_img, lines)
    return line_img

# Python 3 has support for cool math symbols.

def weighted_img(img, initial_img, α=0.8, β=1., λ=0.):
    """
    `img` is the output of the hough_lines(), An image with lines drawn on it.
    Should be a blank image (all black) with lines drawn on it.
    
    `initial_img` should be the image before any processing.
    
    The result image is computed as follows:
    
    initial_img * α + img * β + λ
    NOTE: initial_img and img must be the same shape!
    """
    return cv2.addWeighted(initial_img, α, img, β, λ)

# %% [markdown]
# ## Test Images
#
# Build your pipeline to work on the images in the directory "test_images"
# **You should make sure your pipeline works well on these images before you try the videos.**

# %%
import os
os.listdir("test_images/")
# Out:
# ['solidWhiteCurve.jpg',
#  'solidWhiteRight.jpg',
#  'solidYellowCurve.jpg',
#  'solidYellowCurve2.jpg',
#  'solidYellowLeft.jpg',
#  'whiteCarLaneSwitch.jpg']

# %% [markdown]
# ## Build a Lane Finding Pipeline

# %% [markdown]
# Build the pipeline and run your solution on all test_images. Make copies into the `test_images_output` directory, and you can use the images in your writeup report.
#
# Try tuning the various parameters, especially the low and high Canny thresholds as well as the Hough lines parameters.

# %%
def draw_lane_lines(image):
    # grayscale the image
    gray = grayscale(image)
        
    # Define a kernel size and apply Gaussian smoothing
    kernel_size = 5
    blur_gray = gaussian_blur(gray, kernel_size)
    
    # Define our parameters for Canny and apply
    low_threshold = 50
    high_threshold = 150
    edges = canny(blur_gray, low_threshold, high_threshold)

    # Next we'll create a masked edges image using cv2.fillPoly()
    # This time we are defining a four sided polygon to mask
    imshape = image.shape
    vertices = np.array([[(0,imshape[0]),(465, 320), (475, 320), (imshape[1],imshape[0])]], dtype=np.int32)
    masked_edges = region_of_interest(edges, vertices)
    bw_masked_edges = cv2.cvtColor(masked_edges, cv2.COLOR_GRAY2BGR)
    
    # Define the Hough transform parameters
    # Make a blank the same size as our image to draw on
    rho = 2 # distance resolution in pixels of the Hough grid
    theta = np.pi/180 # angular resolution in radians of the Hough grid
    threshold = 45
    min_line_length = 40
    max_line_gap = 100  
    
    line_image = hough_lines(masked_edges, rho, theta, threshold, min_line_length, max_line_gap)

    # Draw the lines on the edge image
    lines_edges = weighted_img(line_image, image)
    plt.imshow(lines_edges)
    return lines_edges
    
draw_lane_lines(test_images[0])
# Out:
# Coef:  0.564711693911 Intercept:  36.9452128615 intersection_x:  481.602520606
# Point one:  (486, 311) Point two:  (960, 579)
# Coef:  -0.770725375011 Intercept:  680.095071365 intersection_x:  481.602520606
# Point one:  (476, 312) Point two:  (0, 680)
# array([[[ 87, 126, 159],
#         [ 87, 126, 159],
#         [ 87, 126, 159],
#         ...,
#         [ 89, 125, 158],
#         [ 86, 122, 155],
#         [ 82, 118, 151]],
#
#        [[ 87, 126, 159],
#         [ 87, 126, 159],
#         [ 87, 126, 159],
#         ...,
#         [ 89, 125, 158],
#         [ 86, 122, 155],
#         [ 83, 119, 152]],
#
#        [[ 87, 126, 159],
#         [ 87, 126, 159],
#         [ 87, 126, 159],
#         ...,
#         [ 89, 125, 158],
#         [ 86, 122, 155],
#         [ 83, 119, 152]],
#
#        ...,
#        [[ 68,  70,  76],
#         [ 68,  70,  76],
#         [ 68,  70,  76],
#         ...,
#         [ 65,  65,  73],
#         [ 64,  64,  72],
#         [ 63,  63,  71]],
#
#        [[ 69,  69,  75],
#         [ 69,  69,  75],
#         [ 70,  70,  76],
#         ...,
#         [ 62,  64,  71],
#         [ 62,  64,  71],
#         [ 61,  63,  70]],
#
#        [[ 67,  67,  74],
#         [ 67,  67,  74],
#         [ 67,  67,  74],
#         ...,
#         [ 61,  62,  72],
#         [ 60,  62,  71],
#         [ 59,  61,  70]]], dtype=uint8)

# %%
draw_lane_lines(test_images[1])
# Out:
# Coef:  0.637418469415 Intercept:  0.837405069723 intersection_x:  480.037577693
# Point one:  (485, 310) Point two:  (960, 612)
# Coef:  -0.713057889672 Intercept:  649.116805218 intersection_x:  480.037577693
# Point one:  (475, 310) Point two:  (0, 649)
# array([[[144, 157, 167],
#         [114, 129, 141],
#         [107, 125, 143],
#         ...,
#         [109, 123, 142],
#         [117, 127, 141],
#         [149, 156, 168]],
#
#        [[114, 129, 141],
#         [114, 133, 147],
#         [107, 128, 146],
#         ...,
#         [110, 127, 146],
#         [114, 127, 143],
#         [118, 129, 142]],
#
#        [[105, 126, 143],
#         [106, 129, 146],
#         [102, 127, 150],
#         ...,
#         [103, 125, 148],
#         [109, 126, 146],
#         [107, 122, 141]],
#
#        ...,
#        [[ 96,  97, 100],
#         [ 73,  74,  78],
#         [ 66,  67,  71],
#         ...,
#         [ 70,  71,  74],
#         [ 75,  76,  79],
#         [ 96,  97, 100]],
#
#        [[110, 111, 114],
#         [ 84,  85,  88],
#         [ 71,  72,  76],
#         ...,
#         [ 78,  78,  82],
#         [ 87,  88,  91],
#         [111, 112, 115]],
#
#        [[144, 145, 148],
#         [112, 113, 116],
#         [ 94,  94,  98],
#         ...,
#         [ 98,  98, 100],
#         [112, 113, 114],
#         [143, 144, 146]]], dtype=uint8)

# %%
draw_lane_lines(test_images[2])
# Out:
# Coef:  0.562911725955 Intercept:  49.582345191 intersection_x:  473.072832487
# Point one:  (478, 318) Point two:  (960, 589)
# Coef:  -0.72033410321 Intercept:  656.651084371 intersection_x:  473.072832487
# Point one:  (468, 319) Point two:  (0, 656)
# array([[[ 82, 125, 162],
#         [ 82, 125, 162],
#         [ 82, 125, 162],
#         ...,
#         [ 77, 122, 157],
#         [ 75, 121, 155],
#         [ 70, 116, 150]],
#
#        [[ 82, 125, 160],
#         [ 82, 125, 160],
#         [ 82, 125, 160],
#         ...,
#         [ 77, 122, 157],
#         [ 75, 121, 155],
#         [ 70, 116, 150]],
#
#        [[ 82, 126, 158],
#         [ 82, 126, 158],
#         [ 82, 126, 158],
#         ...,
#         [ 78, 122, 157],
#         [ 77, 120, 155],
#         [ 72, 115, 150]],
#
#        ...,
#        [[ 76,  80,  85],
#         [ 76,  80,  85],
#         [ 76,  80,  85],
#         ...,
#         [ 58,  63,  74],
#         [ 58,  63,  74],
#         [ 58,  63,  74]],
#
#        [[ 76,  80,  85],
#         [ 76,  80,  85],
#         [ 76,  80,  85],
#         ...,
#         [ 57,  62,  73],
#         [ 57,  62,  73],
#         [ 57,  62,  73]],
#
#        [[ 75,  79,  84],
#         [ 75,  79,  84],
#         [ 75,  79,  84],
#         ...,
#         [ 58,  62,  71],
#         [ 58,  62,  71],
#         [ 58,  62,  71]]], dtype=uint8)

# %%
draw_lane_lines(test_images[3])
# Out:
# Coef:  0.588513062548 Intercept:  31.4801725782 intersection_x:  472.450859301
# Point one:  (477, 312) Point two:  (960, 596)
# Coef:  -0.751576015188 Intercept:  664.606408894 intersection_x:  472.450859301
# Point one:  (467, 313) Point two:  (0, 664)
# array([[[ 83, 126, 162],
#         [ 83, 126, 162],
#         [ 83, 126, 162],
#         ...,
#         [ 78, 125, 160],
#         [ 76, 123, 158],
#         [ 74, 122, 157]],
#
#        [[ 83, 126, 162],
#         [ 83, 126, 162],
#         [ 83, 126, 162],
#         ...,
#         [ 77, 124, 159],
#         [ 75, 122, 158],
#         [ 72, 121, 156]],
#
#        [[ 82, 126, 161],
#         [ 83, 126, 162],
#         [ 82, 127, 162],
#         ...,
#         [ 75, 124, 159],
#         [ 74, 122, 158],
#         [ 72, 121, 156]],
#
#        ...,
#        [[ 82,  82,  88],
#         [ 82,  82,  88],
#         [ 82,  82,  88],
#         ...,
#         [ 62,  66,  74],
#         [ 62,  66,  74],
#         [ 62,  66,  74]],
#
#        [[ 82,  81,  87],
#         [ 82,  81,  87],
#         [ 82,  81,  87],
#         ...,
#         [ 62,  66,  73],
#         [ 62,  65,  72],
#         [ 62,  65,  72]],
#
#        [[ 79,  78,  85],
#         [ 79,  78,  85],
#         [ 79,  78,  85],
#         ...,
#         [ 62,  65,  72],
#         [ 62,  65,  72],
#         [ 62,  65,  72]]], dtype=uint8)

# %%
draw_lane_lines(test_images[4])
# Out:
# Coef:  0.639448356107 Intercept:  -1.2820477938 intersection_x:  478.827234291
# Point one:  (483, 308) Point two:  (960, 612)
# Coef:  -0.720250126345 Intercept:  649.778616028 intersection_x:  478.827234291
# Point one:  (473, 308) Point two:  (0, 649)
# array([[[147, 157, 168],
#         [115, 127, 142],
#         [106, 123, 142],
#         ...,
#         [102, 122, 141],
#         [112, 129, 142],
#         [146, 159, 171]],
#
#        [[114, 126, 142],
#         [115, 130, 147],
#         [106, 125, 146],
#         ...,
#         [ 99, 123, 144],
#         [110, 127, 144],
#         [113, 128, 142]],
#
#        [[105, 122, 141],
#         [106, 125, 146],
#         [100, 123, 147],
#         ...,
#         [ 94, 120, 145],
#         [ 98, 120, 142],
#         [100, 121, 139]],
#
#        ...,
#        [[103, 102, 107],
#         [ 92,  91,  96],
#         [ 88,  87,  92],
#         ...,
#         [ 66,  66,  74],
#         [ 70,  70,  78],
#         [ 95,  95, 103]],
#
#        [[113, 112, 116],
#         [100,  99, 103],
#         [ 92,  91,  95],
#         ...,
#         [ 70,  70,  78],
#         [ 85,  85,  91],
#         [109, 109, 115]],
#
#        [[141, 140, 144],
#         [111, 110, 114],
#         [102, 102, 106],
#         ...,
#         [ 95,  95, 102],
#         [110, 110, 116],
#         [146, 146, 153]]], dtype=uint8)

# %%
draw_lane_lines(test_images[5])
# Out:
# Coef:  0.592627418783 Intercept:  21.8602443634 intersection_x:  483.576412247
# Point one:  (488, 311) Point two:  (960, 590)
# Coef:  -0.774754933155 Intercept:  683.094096284 intersection_x:  483.576412247
# Point one:  (478, 312) Point two:  (0, 683)
# array([[[ 88, 127, 162],
#         [ 88, 127, 162],
#         [ 88, 127, 162],
#         ...,
#         [ 81, 124, 161],
#         [ 80, 123, 160],
#         [ 75, 118, 155]],
#
#        [[ 88, 127, 162],
#         [ 88, 127, 162],
#         [ 88, 127, 162],
#         ...,
#         [ 81, 124, 161],
#         [ 80, 123, 160],
#         [ 75, 118, 155]],
#
#        [[ 88, 127, 162],
#         [ 88, 127, 162],
#         [ 88, 127, 162],
#         ...,
#         [ 81, 124, 161],
#         [ 80, 123, 160],
#         [ 75, 118, 155]],
#
#        ...,
#        [[ 76,  80,  85],
#         [ 75,  79,  84],
#         [ 75,  79,  84],
#         ...,
#         [ 67,  70,  82],
#         [ 66,  68,  80],
#         [ 63,  66,  78]],
#
#        [[ 75,  79,  84],
#         [ 75,  79,  84],
#         [ 74,  78,  83],
#         ...,
#         [ 67,  70,  80],
#         [ 66,  69,  78],
#         [ 62,  66,  75]],
#
#        [[ 72,  78,  82],
#         [ 71,  77,  82],
#         [ 71,  77,  82],
#         ...,
#         [ 66,  70,  79],
#         [ 65,  68,  78],
#         [ 62,  66,  75]]], dtype=uint8)

# %% [markdown]
# ## Test on Videos
#
# You know what's cooler than drawing lanes over images? Drawing lanes over video!
#
# We can test our solution on two provided videos:
#
# `solidWhiteRight.mp4`
#
# `solidYellowLeft.mp4`
#
# **Note: if you get an `import error` when you run the next cell, try changing your kernel (select the Kernel menu above --> Change Kernel).  Still have problems?  Try relaunching Jupyter Notebook from the terminal prompt. Also, check out [this forum post](https://carnd-forums.udacity.com/questions/22677062/answers/22677109) for more troubleshooting tips.**
#
# **If you get an error that looks like this:**
# ```
# NeedDownloadError: Need ffmpeg exe.
# You can download it by calling:
# imageio.plugins.ffmpeg.download()
# ```
# **Follow the instructions in the error message and check out [this forum post](https://carnd-forums.udacity.com/display/CAR/questions/26218840/import-videofileclip-error) for more troubleshooting tips across operating systems.**

# %%
# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip
from IPython.display import HTML

# %%
def process_image(image):
    # NOTE: The output you return should be a color image (3 channel) for processing video below
    # TODO: put your pipeline here,
    # you should return the final output (image where lines are drawn on lanes)
    result = draw_lane_lines(image)
    return result

# %% [markdown]
# Let's try the one with the solid white lane on the right first ...

# %%
white_output = 'solidWhiteRight.mp4'
## To speed up the testing process you may want to try your pipeline on a shorter subclip of the video
## To do so add .subclip(start_second,end_second) to the end of the line below
## Where start_second and end_second are integer values representing the start and end of the subclip
## You may also uncomment the following line for a subclip of the first 5 seconds
#clip1 = VideoFileClip("test_videos/solidWhiteRight.mp4").subclip(0,5)
clip1 = VideoFileClip("test_videos/solidWhiteRight.mp4")
white_clip = clip1.fl_image(process_image) #NOTE: this function expects color images!!
# %time white_clip.write_videofile(white_output, audio=True)
# Out:
# Coef:  0.613989640769 Intercept:  12.3219355054 intersection_x:  479.151870663
# Point one:  (484, 309) Point two:  (960, 601)
# Coef:  -0.715122603843 Intercept:  649.168553832 intersection_x:  479.151870663
# Point one:  (474, 310) Point two:  (0, 649)
# [MoviePy] >>>> Building video solidWhiteRight.mp4
# [MoviePy] Writing audio in solidWhiteRightTEMP_MPY_wvf_snd.mp3
#   0%|          | 0/195 [00:00<?, ?it/s]
#
#  52%|█████▏    | 101/195 [00:00<00:00, 616.79it/s]
#
# 100%|██████████| 195/195 [00:00<00:00, 822.94it/s]
# [MoviePy] Done.
# [MoviePy] Writing video solidWhiteRight.mp4
#   0%|          | 0/222 [00:00<?, ?it/s]
# Coef:  0.613989640769 Intercept:  12.3219355054 intersection_x:  479.151870663
# Point one:  (484, 309) Point two:  (960, 601)
# Coef:  -0.715122603843 Intercept:  649.168553832 intersection_x:  479.151870663
# Point one:  (474, 310) Point two:  (0, 649)
# Coef:  0.611924674716 Intercept:  11.0023766839 intersection_x:  479.583741708
# Point one:  (484, 307) Point two:  (960, 598)
# Coef:  -0.720919504682 Intercept:  650.212775353 intersection_x:  479.583741708
# Point one:  (474, 308) Point two:  (0, 650)
#   1%|          | 2/222 [00:00<00:19, 11.46it/s]
# Coef:  0.599252368185 Intercept:  20.844202234 intersection_x:  475.896042592
# Point one:  (480, 309) Point two:  (960, 596)
# Coef:  -0.726024850679 Intercept:  651.538386029 intersection_x:  475.896042592
# Point one:  (470, 309) Point two:  (0, 651)
#   2%|▏         | 5/222 [00:00<00:16, 13.37it/s]
# Coef:  0.612940312291 Intercept:  13.4670790861 intersection_x:  478.475865894
# Point one:  (483, 309) Point two:  (960, 601)
# Coef:  -0.716511769199 Intercept:  649.577814941 intersection_x:  478.475865894
# Point one:  (473, 310) Point two:  (0, 649)
# Coef:  0.605966270596 Intercept:  16.5257774098 intersection_x:  476.524739229
# Point one:  (481, 308) Point two:  (960, 598)
# Coef:  -0.733118857494 Intercept:  654.632968878 intersection_x:  476.524739229
# Point one:  (471, 308) Point two:  (0, 654)
# Coef:  0.610497674401 Intercept:  13.4489833622 intersection_x:  477.742612104
# Point one:  (482, 308) Point two:  (960, 599)
# Coef:  -0.726131687243 Intercept:  652.013786008 intersection_x:  477.742612104
# Point one:  (472, 308) Point two:  (0, 652)
#   3%|▎         | 7/222 [00:00<00:14, 14.35it/s]
# Coef:  0.609978186363 Intercept:  13.4836024687 intersection_x:  478.828053801
# Point one:  (483, 308) Point two:  (960, 599)
# Coef:  -0.710106382979 Intercept:  645.57712766 intersection_x:  478.828053801
# Point one:  (473, 309) Point two:  (0, 645)
#   5%|▍         | 10/222 [00:00<00:13, 16.00it/s]
# Coef:  0.600513086591 Intercept:  14.5430646835 intersection_x:  480.077058053
# Point one:  (485, 305) Point two:  (960, 591)
# Coef:  -0.71577090232 Intercept:  646.460809642 intersection_x:  480.077058053
# Point one:  (475, 306) Point two:  (0, 646)
# Coef:  0.615614932576 Intercept:  11.0486113407 intersection_x:  478.077103128
# Point one:  (483, 308) Point two:  (960, 602)
# Coef:  -0.707154359328 Intercept:  643.434322521 intersection_x:  478.077103128
# Point one:  (473, 308) Point two:  (0, 643)
# Coef:  0.592320579142 Intercept:  27.0023889268 intersection_x:  476.658401553
# Point one:  (481, 312) Point two:  (960, 595)
# Coef:  -0.712500488969 Intercept:  648.956313566 intersection_x:  476.658401553
# Point one:  (471, 312) Point two:  (0, 648)
# Coef:  0.624808046162 Intercept:  9.8860410829 intersection_x:  478.873168051
# Point one:  (483, 312) Point two:  (960, 609)
# Coef:  -0.725107624334 Intercept:  656.324434815 intersection_x:  478.873168051
# Point one:  (473, 312) Point two:  (0, 656)
#   5%|▌         | 12/222 [00:00<00:12, 16.83it/s]
#
#   6%|▋         | 14/222 [00:00<00:12, 16.49it/s]
# Coef:  0.633195354166 Intercept:  5.91428193881 intersection_x:  478.32148664
# Point one:  (483, 311) Point two:  (960, 613)
# Coef:  -0.724488732023 Intercept:  655.323752432 intersection_x:  478.32148664
# Point one:  (473, 312) Point two:  (0, 655)
# Coef:  0.633305805531 Intercept:  5.10063588308 intersection_x:  479.624932329
# Point one:  (484, 312) Point two:  (960, 613)
# Coef:  -0.708057774069 Intercept:  648.452051977 intersection_x:  479.624932329
# Point one:  (474, 312) Point two:  (0, 648)
# Coef:  0.636832059275 Intercept:  0.212451912374 intersection_x:  478.312547231
# Point one:  (483, 308) Point two:  (960, 611)
# Coef:  -0.725196502249 Intercept:  651.687802577 intersection_x:  478.312547231
# Point one:  (473, 308) Point two:  (0, 651)
# Coef:  0.633148559698 Intercept:  3.52442213903 intersection_x:  477.213306048
# Point one:  (482, 308) Point two:  (960, 611)
# Coef:  -0.713814399621 Intercept:  646.31306908 intersection_x:  477.213306048
# Point one:  (472, 309) Point two:  (0, 646)
#   7%|▋         | 16/222 [00:00<00:13, 14.84it/s]
# Coef:  0.655187198419 Intercept:  -12.9279281243 intersection_x:  482.166984723
# Point one:  (487, 306) Point two:  (960, 616)
# Coef:  -0.696930085826 Intercept:  639.018385811 intersection_x:  482.166984723
# Point one:  (477, 306) Point two:  (0, 639)
# Coef:  0.655574530964 Intercept:  -14.3399077068 intersection_x:  483.007219428
# Point one:  (488, 305) Point two:  (960, 615)
# Coef:  -0.68426056554 Intercept:  632.810116747 intersection_x:  483.007219428
# Point one:  (478, 305) Point two:  (0, 632)
# Coef:  0.648898235017 Intercept:  -9.93728273342 intersection_x:  481.684373628
# Point one:  (486, 305) Point two:  (960, 613)
# Coef:  -0.69789997835 Intercept:  638.794371076 intersection_x:  481.684373628
# Point one:  (476, 306) Point two:  (0, 638)
#   8%|▊         | 18/222 [00:01<00:15, 13.46it/s]
#   9%|▉         | 20/222 [00:01<00:14, 14.17it/s]
# Coef:  0.637903875878 Intercept:  -0.0617799119089 intersection_x:  481.592765388
# Point one:  (486, 310) Point two:  (960, 612)
# Coef:  -0.67381189764 Intercept:  631.651046859 intersection_x:  481.592765388
# Point one:  (476, 310) Point two:  (0, 631)
# Coef:  0.62691741134 Intercept:  7.12823128668 intersection_x:  477.979888191
# Point one:  (482, 309) Point two:  (960, 608)
# Coef:  -0.710444352159 Intercept:  646.360257475 intersection_x:  477.979888191
# Point one:  (472, 310) Point two:  (0, 646)
# Coef:  0.637172232529 Intercept:  1.00032158318 intersection_x:  481.030463114
# Point one:  (486, 310) Point two:  (960, 612)
# Coef:  -0.700303030303 Intercept:  644.366666667 intersection_x:  481.030463114
# Point one:  (476, 311) Point two:  (0, 644)
# Coef:  0.636811421992 Intercept:  1.28952400622 intersection_x:  480.475559777
# Point one:  (485, 310) Point two:  (960, 612)
# Coef:  -0.715683824754 Intercept:  651.130434783 intersection_x:  480.475559777
# Point one:  (475, 310) Point two:  (0, 651)
# Coef:  0.643154002253 Intercept:  -1.01802522338 intersection_x:  480.13068261
# Point one:  (485, 310) Point two:  (960, 616)
# Coef:  -0.699807500768 Intercept:
#  10%|█         | 23/222 [00:01<00:12, 15.82it/s]
#  12%|█▏        | 26/222 [00:01<00:11, 16.34it/s]
# 643.778997941 intersection_x:  480.13068261
# Point one:  (475, 311) Point two:  (0, 643)
# Coef:  0.631467579978 Intercept:  3.48225700534 intersection_x:  479.046662718
# Point one:  (484, 309) Point two:  (960, 609)
# Coef:  -0.72098628171 Intercept:  651.370765927 intersection_x:  479.046662718
# Point one:  (474, 309) Point two:  (0, 651)
# Coef:  0.636520745122 Intercept:  0.220987748706 intersection_x:  480.09051652
# Point one:  (485, 308) Point two:  (960, 611)
# Coef:  -0.717895382295 Intercept:  650.463325943 intersection_x:  480.09051652
# Point one:  (475, 309) Point two:  (0, 650)
# Coef:  0.636513015897 Intercept:  1.42312995383 intersection_x:  478.615640423
# Point one:  (483, 309) Point two:  (960, 612)
# Coef:  -0.70301904367 Intercept:  642.544124511 intersection_x:  478.615640423
# Point one:  (473, 309) Point two:  (0, 642)
# Coef:  0.637377099071 Intercept:  0.421931911673 intersection_x:  481.240359201
# Point one:  (486, 310) Point two:  (960, 612)
# Coef:  -0.699775256034 Intercept:  643.913611589 intersection_x:  481.240359201
# Point one:  (476, 310) Point two:  (0, 643)
#  13%|█▎        | 28/222 [00:01<00:11, 16.89it/s]
# Coef:  0.640082380719 Intercept:  -0.372008941243 intersection_x:  478.263538197
# Point one:  (483, 308) Point two:  (960, 614)
# Coef:  -0.723866600145 Intercept:  651.955056567 intersection_x:  478.263538197
# Point one:  (473, 309) Point two:  (0, 651)
# Coef:  0.640630687979 Intercept:  -3.46086125163 intersection_x:  482.992901241
# Point one:  (487, 309) Point two:  (960, 611)
# Coef:  -0.699498525074 Intercept:  643.812035398 intersection_x:  482.992901241
# Point one:  (477, 309) Point two:  (0, 643)
# Coef:  0.624414815511 Intercept:  5.68753998571 intersection_x:  479.196569713
# Point one:  (484, 308) Point two:  (960, 605)
# Coef:  -0.726025641026 Intercept:  652.813974359 intersection_x:  479.196569713
# Point one:  (474, 308) Point two:  (0, 652)
# Coef:  0.625910567199 Intercept:  4.73948894527 intersection_x:  479.662275166
# Point one:  (484, 308) Point two:  (960, 605)
# Coef:  -0.724828258967 Intercept:  652.637947459 intersection_x:  479.662275166
# Point one:  (474, 308) Point two:  (0, 652)
#  14%|█▍        | 31/222 [00:01<00:12, 15.63it/s]
#  15%|█▌        | 34/222 [00:02<00:11, 16.60it/s]
# Coef:  0.636696955986 Intercept:  -0.718954093268 intersection_x:  479.244065556
# Point one:  (484, 307) Point two:  (960, 610)
# Coef:  -0.727455196125 Intercept:  653.042869322 intersection_x:  479.244065556
# Point one:  (474, 308) Point two:  (0, 653)
# Coef:  0.637171243623 Intercept:  -1.69397244701 intersection_x:  480.270671047
# Point one:  (485, 307) Point two:  (960, 609)
# Coef:  -0.714032023066 Intercept:  647.249327167 intersection_x:  480.270671047
# Point one:  (475, 307) Point two:  (0, 647)
# Coef:  0.616922536828 Intercept:  9.59199578726 intersection_x:  478.976028275
# Point one:  (483, 308) Point two:  (960, 601)
# Coef:  -0.728136501862 Intercept:  653.843031934 intersection_x:  478.976028275
# Point one:  (473, 308) Point two:  (0, 653)
# Coef:  0.64328928431 Intercept:  -4.40045374248 intersection_x:  479.725599632
# Point one:  (484, 307) Point two:  (960, 613)
# Coef:  -0.736058186657 Intercept:  657.307838868 intersection_x:  479.725599632
# Point one:  (474, 307) Point two:  (0, 657)
# Coef:  0.637655652644 Intercept:  1.65858359871 intersection_x:  478.86567434
# Point one:  (483, 310) Point two:  (960, 613)
# Coef:  -0.714467642822 Intercept:  649.144017273 intersection_x:  478.86567434
#  16%|█▌        | 36/222 [00:02<00:12, 14.98it/s]
# Point one:  (473, 310) Point two:  (0, 649)
# Coef:  0.636982686626 Intercept:  1.43021635188 intersection_x:  481.206925653
# Point one:  (486, 311) Point two:  (960, 612)
# Coef:  -0.698169249734 Intercept:  643.914574927 intersection_x:  481.206925653
# Point one:  (476, 311) Point two:  (0, 643)
# Coef:  0.634340192589 Intercept:  3.51225277604 intersection_x:  479.820019335
# Point one:  (484, 311) Point two:  (960, 612)
# Coef:  -0.706783501167 Intercept:  647.010249445 intersection_x:  479.820019335
# Point one:  (474, 311) Point two:  (0, 647)
#  17%|█▋        | 38/222 [00:02<00:11, 16.16it/s]
#  18%|█▊        | 40/222 [00:02<00:11, 16.00it/s]
# Coef:  0.631541367446 Intercept:  5.9586880181 intersection_x:  477.818301444
# Point one:  (482, 310) Point two:  (960, 612)
# Coef:  -0.712286947505 Intercept:  648.0644509 intersection_x:  477.818301444
# Point one:  (472, 311) Point two:  (0, 648)
# Coef:  0.641435581148 Intercept:  -0.943504844228 intersection_x:  478.008089401
# Point one:  (483, 308) Point two:  (960, 614)
# Coef:  -0.736715140602 Intercept:  657.823688566 intersection_x:  478.008089401
# Point one:  (473, 309) Point two:  (0, 657)
# Coef:  0.656743961479 Intercept:  -10.1301255482 intersection_x:  479.886448284
# Point one:  (484, 308) Point two:  (960, 620)
# Coef:  -0.707648032233 Intercept:  644.623102381 intersection_x:  479.886448284
# Point one:  (474, 308) Point two:  (0, 644)
# Coef:  0.66854655805 Intercept:  -18.8783820646 intersection_x:  480.015254836
# Point one:  (485, 305) Point two:  (960, 622)
# Coef:  -0.736184210526 Intercept:  655.413815789 intersection_x:  480.015254836
# Point one:  (475, 305) Point two:  (0, 655)
#  19%|█▉        | 42/222 [00:02<00:12, 14.03it/s]
#  20%|██        | 45/222 [00:02<00:12, 14.38it/s]
# Coef:  0.665565412054 Intercept:  -17.92441694 intersection_x:  478.149165306
# Point one:  (483, 303) Point two:  (960, 621)
# Coef:  -0.760334755294 Intercept:  663.868557887 intersection_x:  478.149165306
# Point one:  (473, 304) Point two:  (0, 663)
# Coef:  0.650114618993 Intercept:  -8.33056620153 intersection_x:  477.250068336
# Point one:  (482, 305) Point two:  (960, 615)
# Coef:  -0.738241792929 Intercept:  654.262626263 intersection_x:  477.250068336
# Point one:  (472, 305) Point two:  (0, 654)
# Coef:  0.646171316727 Intercept:  -6.00326637735 intersection_x:  477.964140303
# Point one:  (482, 306) Point two:  (960, 614)
# Coef:  -0.720863958736 Intercept:  647.390573823 intersection_x:  477.964140303
# Point one:  (472, 306) Point two:  (0, 647)
# Coef:  0.668546464482 Intercept:  -21.0258136822 intersection_x:  480.411808135
# Point one:  (485, 303) Point two:  (960, 620)
# Coef:  -0.725042986981 Intercept:  648.471014493
#  21%|██        | 47/222 [00:02<00:11, 15.17it/s]
#  intersection_x:  480.411808135
# Point one:  (475, 303) Point two:  (0, 648)
# Coef:  0.660276901029 Intercept:  -15.092783157 intersection_x:  476.592114979
# Point one:  (481, 302) Point two:  (960, 618)
# Coef:  -0.770905946888 Intercept:  666.997677253 intersection_x:  476.592114979
# Point one:  (471, 303) Point two:  (0, 666)
# Coef:  0.652095156645 Intercept:  -11.5109299911 intersection_x:  477.823266801
# Point one:  (482, 303) Point two:  (960, 614)
# Coef:  -0.761785316133 Intercept:  664.074056378 intersection_x:  477.823266801
# Point one:  (472, 303) Point two:  (0, 664)
# Coef:  0.647958489105 Intercept:  -7.58083673505 intersection_x:  476.242057223
# Point one:  (481, 304) Point two:  (960, 614)
# Coef:  -0.761526575472
#  22%|██▏       | 49/222 [00:03<00:12, 13.34it/s]
#  Intercept:  663.675230044 intersection_x:  476.242057223
# Point one:  (471, 304) Point two:  (0, 663)
# Coef:  0.636293028749 Intercept:  -0.759249069171 intersection_x:  478.098985091
# Point one:  (483, 306) Point two:  (960, 610)
# Coef:  -0.72268401027 Intercept:  648.966294048 intersection_x:  478.098985091
# Point one:  (473, 307) Point two:  (0, 648)
# Coef:  0.645783100715 Intercept:  -5.86453118034 intersection_x:  479.929833691
# Point one:  (484, 307) Point two:  (960, 614)
# Coef:  -0.715552405629 Intercept:  647.480991977 intersection_x:  479.929833691
# Point one:  (474, 307) Point two:  (0, 647)
#  23%|██▎       | 51/222 [00:03<00:12, 14.00it/s]
# Coef:  0.642511306655 Intercept:  -5.47559522256 intersection_x:  477.048745375
# Point one:  (482, 304) Point two:  (960, 611)
# Coef:  -0.722539549933 Intercept:  645.720203286 intersection_x:  477.048745375
# Point one:  (472, 304) Point two:  (0, 645)
# Coef:  0.605920703571 Intercept:  16.2538884403 intersection_x:  475.130221054
# Point one:  (480, 307) Point two:  (960, 597)
# Coef:  -0.715734085309 Intercept:  644.212020438 intersection_x:  475.130221054
# Point one:  (470, 307) Point two:  (0, 644)
# Coef:  0.639160787447 Intercept:  -1.60658978107 intersection_x:  479.969778566
# Point one:  (484, 308) Point two:  (960, 611)
# Coef:  -0.672458665034 Intercept:  627.931108389 intersection_x:  479.969778566
# Point one:  (474, 308) Point two:  (0, 627)
#  24%|██▍       | 54/222 [00:03<00:16, 10.15it/s]
#  26%|██▌       | 57/222 [00:03<00:13, 12.31it/s]
# Coef:  0.653734583259 Intercept:  -9.39936175765 intersection_x:  479.288589795
# Point one:  (484, 307) Point two:  (960, 618)
# Coef:  -0.680768705472 Intercept:  630.212837575 intersection_x:  479.288589795
# Point one:  (474, 307) Point two:  (0, 630)
# Coef:  0.659477407671 Intercept:  -11.2659723946 intersection_x:  479.474574232
# Point one:  (484, 308) Point two:  (960, 621)
# Coef:  -0.681464527933 Intercept:  631.681591249 intersection_x:  479.474574232
# Point one:  (474, 308) Point two:  (0, 631)
# Coef:  0.666378929614 Intercept:  -14.9687455197 intersection_x:  480.35666484
# Point one:  (485, 308) Point two:  (960, 624)
# Coef:  -0.680318847317 Intercept:  631.926507155 intersection_x:  480.35666484
# Point one:  (475, 308) Point two:  (0, 631)
# Coef:  0.634089981214 Intercept:  3.44124678266 intersection_x:  480.612272258
# Point one:  (485, 311) Point two:  (960, 612)
# Coef:  -0.666318340594 Intercept:  628.43344519 intersection_x:  480.612272258
# Point one:  (475, 311) Point two:  (0, 628)
#  27%|██▋       | 59/222 [00:04<00:22,  7.10it/s]
#  27%|██▋       | 61/222 [00:04<00:18,  8.75it/s]
# Coef:  0.646034356566 Intercept:  -3.30939279318 intersection_x:  475.377659808
# Point one:  (480, 307) Point two:  (960, 616)
# Coef:  -0.741243781095 Intercept:  656.171641791 intersection_x:  475.377659808
# Point one:  (470, 307) Point two:  (0, 656)
# Coef:  0.660744965434 Intercept:  -14.9645419448 intersection_x:  481.233124749
# Point one:  (486, 306) Point two:  (960, 619)
# Coef:  -0.700859956616 Intercept:  640.284849368 intersection_x:  481.233124749
# Point one:  (476, 306) Point two:  (0, 640)
# Coef:  0.655767957895 Intercept:  -11.2607589952 intersection_x:  477.125478931
# Point one:  (482, 304) Point two:  (960, 618)
# Coef:  -0.716703266491 Intercept:  643.580231259 intersection_x:  477.125478931
# Point one:  (472, 305) Point two:  (0, 643)
# Coef:  0.654238339086 Intercept:  -8.85531130349 intersection_x:  480.972748704
# Point one:  (485, 309) Point two:  (960, 619)
# Coef:  -0.687181383824 Intercept:  636.33101999 intersection_x:  480.972748704
# Point one:  (475, 309) Point two:  (0, 636)
#  28%|██▊       | 63/222 [00:04<00:15, 10.49it/s]
#  30%|██▉       | 66/222 [00:04<00:12, 12.68it/s]
# Coef:  0.660575891261 Intercept:  -11.4153126309 intersection_x:  480.968782286
# Point one:  (485, 309) Point two:  (960, 622)
# Coef:  -0.681138680321 Intercept:  633.907511039 intersection_x:  480.968782286
# Point one:  (475, 309) Point two:  (0, 633)
# Coef:  0.652809815736 Intercept:  -6.80995494641 intersection_x:  478.429388202
# Point one:  (483, 308) Point two:  (960, 619)
# Coef:  -0.686737444919 Intercept:  634.068821437 intersection_x:  478.429388202
# Point one:  (473, 308) Point two:  (0, 634)
# Coef:  0.658132931509 Intercept:  -9.30086192389 intersection_x:  479.414340605
# Point one:  (484, 309) Point two:  (960, 622)
# Coef:  -0.667608683002 Intercept:  626.278680009 intersection_x:  479.414340605
# Point one:  (474, 309) Point two:  (0, 626)
# Coef:  0.647491991296 Intercept:  -6.5504393454 intersection_x:  480.656523003
# Point one:  (485, 307) Point two:  (960, 615)
# Coef:  -0.675318471338 Intercept:  629.267038217 intersection_x:  480.656523003
# Point one:  (475, 308) Point two:  (0, 629)
# Coef:  0.655571668291 Intercept:  -9.4813317804 intersection_x:  478.115003854
# Point one:  (483, 307) Point two:  (960, 619)
# Coef:  -0.685040323976 Intercept:  631.485376069 intersection_x:  478.115003854
# Point one:  (473, 307) Point two:  (0, 631)
#  31%|███       | 68/222 [00:04<00:10, 14.08it/s]
#  32%|███▏      | 71/222 [00:05<00:09, 15.92it/s]
# Coef:  0.661066682546 Intercept:  -15.1971779917 intersection_x:  481.405255836
# Point one:  (486, 306) Point two:  (960, 619)
# Coef:  -0.681248679383 Intercept:  631.00049223 intersection_x:  481.405255836
# Point one:  (476, 306) Point two:  (0, 631)
# Coef:  0.617335238051 Intercept:  13.1430274264 intersection_x:  475.401961541
# Point one:  (480, 309) Point two:  (960, 605)
# Coef:  -0.688058459906 Intercept:  633.729752019 intersection_x:  475.401961541
# Point one:  (470, 310) Point two:  (0, 633)
# Coef:  0.644527282419 Intercept:  -1.37967484009 intersection_x:  477.872387801
# Point one:  (482, 309) Point two:  (960, 617)
# Coef:  -0.666669721145 Intercept:  625.20516813 intersection_x:  477.872387801
# Point one:  (472, 309) Point two:  (0, 625)
# Coef:  0.650948688902 Intercept:  -4.94237993738 intersection_x:  476.546206736
# Point one:  (481, 308) Point two:  (960, 619)
# Coef:  -0.684706862905 Intercept:  631.559206782 intersection_x:  476.546206736
# Point one:  (471, 308) Point two:  (0, 631)
# Coef:  0.664030094921 Intercept:  -12.263873417 intersection_x:  477.22333339
# Point one:  (482, 307) Point two:  (960, 625)
# Coef:  -0.68115890954 Intercept:  629.691707331 intersection_x:  477.22333339
# Point one:  (472, 308) Point two:  (0, 629)
#  33%|███▎      | 74/222 [00:05<00:08, 17.47it/s]
# Coef:  0.664044341566 Intercept:  -12.5716373335 intersection_x:  479.950777285
# Point one:  (484, 309) Point two:  (960, 624)
# Coef:  -0.663432265366 Intercept:  624.551791992 intersection_x:  479.950777285
# Point one:  (474, 309) Point two:  (0, 624)
# Coef:  0.634524753298 Intercept:  3.56319508936 intersection_x:  474.682053272
# Point one:  (479, 307) Point two:  (960, 612)
# Coef:  -0.698144689449 Intercept:  636.157462505 intersection_x:  474.682053272
# Point one:  (469, 308) Point two:  (0, 636)
# Coef:  0.659732397287 Intercept:  -10.7407904855 intersection_x:  476.688294811
# Point one:  (481, 307) Point two:  (960, 622)
# Coef:  -0.691298277038 Intercept:  633.279717896 intersection_x:  476.688294811
# Point one:  (471, 307) Point two:  (0, 633)
# Coef:  0.66213208846 Intercept:  -12.275358658 intersection_x:  479.852902067
# Point one:  (484, 308) Point two:  (960, 623)
# Coef:  -0.667437100804 Intercept:  625.722275309 intersection_x:  479.852902067
# Point one:  (474, 308) Point two:  (0, 625)
# Coef:  0.659331407898 Intercept:  -8.79485679687 intersection_x:  477.664478017
# Point one:  (482, 309) Point two:  (960, 624)
# Coef:  -0.659885624867 Intercept:  621.348258549 intersection_x:  477.664478017
# Point one:  (472, 309) Point two:  (0, 621)
#  35%|███▍      | 77/222 [00:05<00:07, 18.70it/s]
#  36%|███▌      | 80/222 [00:05<00:07, 18.90it/s]
# Coef:  0.66270038724 Intercept:  -9.34831135782 intersection_x:  474.270427357
# Point one:  (479, 308) Point two:  (960, 626)
# Coef:  -0.69074613411 Intercept:  632.551348728 intersection_x:  474.270427357
# Point one:  (469, 308) Point two:  (0, 632)
# Coef:  0.665952592055 Intercept:  -12.572501395 intersection_x:  480.300860764
# Point one:  (485, 310) Point two:  (960, 626)
# Coef:  -0.63135667015 Intercept:  610.526253918 intersection_x:  480.300860764
# Point one:  (475, 310) Point two:  (0, 610)
# Coef:  0.670176008908 Intercept:  -13.1654985318 intersection_x:  474.642796237
# Point one:  (479, 308) Point two:  (960, 630)
# Coef:  -0.685790788732 Intercept:  630.434373905 intersection_x:  474.642796237
# Point one:  (469, 308) Point two:  (0, 630)
# Coef:  0.675107877812 Intercept:  -16.2140555314 intersection_x:  475.357588891
# Point one:  (480, 308) Point two:  (960, 631)
# Coef:  -0.684043441938 Intercept:  629.868838764 intersection_x:  475.357588891
# Point one:  (470, 308) Point two:  (0, 629)
#  37%|███▋      | 83/222 [00:05<00:07, 19.11it/s]
# Coef:  0.678477927545 Intercept:  -19.2261917187 intersection_x:  474.806584495
# Point one:  (479, 306) Point two:  (960, 632)
# Coef:  -0.698484301455 Intercept:  634.564541212 intersection_x:  474.806584495
# Point one:  (469, 306) Point two:  (0, 634)
# Coef:  0.666368509839 Intercept:  -12.2851074665 intersection_x:  477.158756182
# Point one:  (482, 309) Point two:  (960, 627)
# Coef:  -0.661307751388 Intercept:  621.227245953 intersection_x:  477.158756182
# Point one:  (472, 308) Point two:  (0, 621)
# Coef:  0.647349006492 Intercept:  -3.0612236868 intersection_x:  476.907023368
# Point one:  (481, 308) Point two:  (960, 618)
# Coef:  -0.661385188052 Intercept:  621.083305413 intersection_x:  476.907023368
# Point one:  (471, 308) Point two:  (0, 621)
# Coef:  0.654194840638 Intercept:  -7.07257586737 intersection_x:  480.393578358
# Point one:  (485, 310) Point two:  (960, 620)
# Coef:  -0.638770729011 Intercept:  614.05978083 intersection_x:  480.393578358
# Point one:  (475, 310) Point two:  (0, 614)
# Coef:  0.67674721876 Intercept:  -19.1894693717 intersection_x:  480.75239069
# Point one:  (485, 309) Point two:  (960, 630)
# Coef:  -0.650266615624 Intercept:  618.775603988 intersection_x:  480.75239069
# Point one:  (475, 309) Point two:  (0, 618)
#  39%|███▊      | 86/222 [00:05<00:06, 20.40it/s]
#  40%|████      | 89/222 [00:05<00:06, 20.81it/s]
# Coef:  0.669392246487 Intercept:  -14.166006433 intersection_x:  477.008805927
# Point one:  (482, 308) Point two:  (960, 628)
# Coef:  -0.673555619264 Intercept:  626.431951431 intersection_x:  477.008805927
# Point one:  (472, 308) Point two:  (0, 626)
# Coef:  0.664278117112 Intercept:  -10.9722754139 intersection_x:  478.153875788
# Point one:  (483, 309) Point two:  (960, 626)
# Coef:  -0.65941269485 Intercept:  621.95561667 intersection_x:  478.153875788
# Point one:  (473, 309) Point two:  (0, 621)
# Coef:  0.685090048994 Intercept:  -24.4879074655 intersection_x:  478.101233371
# Point one:  (483, 306) Point two:  (960, 633)
# Coef:  -0.686691820025 Intercept:  631.362696029 intersection_x:  478.101233371
# Point one:  (473, 306) Point two:  (0, 631)
# Coef:  0.665706355225 Intercept:  -10.60760261 intersection_x:  477.43797202
# Point one:  (482, 310) Point two:  (960, 628)
# Coef:  -0.659336419753 Intercept:  622.018132716 intersection_x:  477.43797202
# Point one:  (472, 310) Point two:  (0, 622)
# Coef:  0.684491556434 Intercept:  -23.9486197122 intersection_x:  482.7314806
# Point one:  (487, 309) Point two:  (960, 633)
# Coef:  -0.644759893985 Intercept:  617.722901038 intersection_x:  482.7314806
# Point one:  (477, 309) Point two:  (0, 617)
#  41%|████▏     | 92/222 [00:05<00:05, 21.81it/s]
# Coef:  0.693676585923 Intercept:  -27.9125067906 intersection_x:  481.219613759
# Point one:  (486, 309) Point two:  (960, 638)
# Coef:  -0.659482758621 Intercept:  623.254310345 intersection_x:  481.219613759
# Point one:  (476, 309) Point two:  (0, 623)
# Coef:  0.702068552381 Intercept:  -33.2588598048 intersection_x:  481.675694008
# Point one:  (486, 308) Point two:  (960, 640)
# Coef:  -0.666332611452 Intercept:  625.866720466 intersection_x:  481.675694008
# Point one:  (476, 308) Point two:  (0, 625)
# Coef:  0.687925638141 Intercept:  -23.7167086378 intersection_x:  482.186542753
# Point one:  (487, 311) Point two:  (960, 636)
# Coef:  -0.64379851335 Intercept:  618.42275587 intersection_x:  482.186542753
# Point one:  (477, 311) Point two:  (0, 618)
# Coef:  0.686045159609 Intercept:  -24.0143268844 intersection_x:  482.71436524
# Point one:  (487, 310) Point two:  (960, 634)
# Coef:  -0.638318940988 Intercept:  615.275249281 intersection_x:  482.71436524
# Point one:  (477, 310) Point two:  (0, 615)
#  43%|████▎     | 95/222 [00:06<00:08, 14.60it/s]
#  44%|████▎     | 97/222 [00:06<00:07, 15.68it/s]
# Coef:  0.688692358957 Intercept:  -27.1900959682 intersection_x:  482.540507141
# Point one:  (487, 308) Point two:  (960, 633)
# Coef:  -0.652994707594 Intercept:  620.22826155 intersection_x:  482.540507141
# Point one:  (477, 308) Point two:  (0, 620)
# Coef:  0.696752553638 Intercept:  -31.2397672004 intersection_x:  482.013858847
# Point one:  (487, 308) Point two:  (960, 637)
# Coef:  -0.663876528787 Intercept:  624.602307278 intersection_x:  482.013858847
# Point one:  (477, 307) Point two:  (0, 624)
# Coef:  0.695370538552 Intercept:  -32.7809099991 intersection_x:  481.301870021
# Point one:  (486, 305) Point two:  (960, 634)
# Coef:  -0.680276601207 Intercept:  629.320630856 intersection_x:  481.301870021
# Point one:  (476, 305) Point two:  (0, 629)
# Coef:  0.695728844325 Intercept:  -34.5081881067 intersection_x:  485.79497979
# Point one:  (490, 306) Point two:  (960, 633)
# Coef:  -0.653807086241 Intercept:  621.089592009 intersection_x:  485.79497979
# Point one:  (480, 306) Point two:  (0, 621)
# Coef:  0.700213054187 Intercept:  -38.2440504926 intersection_x:  486.405699027
# Point one:  (491, 305) Point two:  (960, 633)
# Coef:  -0.650230790335 Intercept:  618.6195317 intersection_x:  486.405699027
# Point one:  (481, 305) Point two:  (0, 618)
#  45%|████▌     | 100/222 [00:06<00:07, 17.36it/s]
#  46%|████▋     | 103/222 [00:06<00:06, 19.12it/s]
# Coef:  0.70084962849 Intercept:  -37.1672758248 intersection_x:  487.532563603
# Point one:  (492, 308) Point two:  (960, 635)
# Coef:  -0.637934524505 Intercept:  615.533594396 intersection_x:  487.532563603
# Point one:  (482, 307) Point two:  (0, 615)
# Coef:  0.693525706794 Intercept:  -29.4906312699 intersection_x:  482.043826441
# Point one:  (487, 308) Point two:  (960, 636)
# Coef:  -0.681641042622 Intercept:  633.400010613 intersection_x:  482.043826441
# Point one:  (477, 308) Point two:  (0, 633)
# Coef:  0.683494132966 Intercept:  -24.253984266 intersection_x:  480.125932698
# Point one:  (485, 307) Point two:  (960, 631)
# Coef:  -0.706861160626 Intercept:  643.291647851 intersection_x:  480.125932698
# Point one:  (475, 307) Point two:  (0, 643)
# Coef:  0.650049240106 Intercept:  -6.2973823713 intersection_x:  482.216349025
# Point one:  (487, 310) Point two:  (960, 617)
# Coef:  -0.673181408556 Intercept:  631.786069944 intersection_x:  482.216349025
# Point one:  (477, 310) Point two:  (0, 631)
# Coef:  0.677666125732 Intercept:  -22.1965003937 intersection_x:  484.434800974
# Point one:  (489, 309) Point two:  (960, 628)
# Coef:  -0.665061327561 Intercept:  628.267406205 intersection_x:  484.434800974
# Point one:  (479, 309) Point two:  (0, 628)
#  48%|████▊     | 106/222 [00:06<00:05, 19.75it/s]
# Coef:  0.688310560829 Intercept:  -29.5486269511 intersection_x:  484.487661325
# Point one:  (489, 307) Point two:  (960, 631)
# Coef:  -0.68232413458 Intercept:  634.506971158 intersection_x:  484.487661325
# Point one:  (479, 307) Point two:  (0, 634)
# Coef:  0.669172555104 Intercept:  -17.8438212691 intersection_x:  483.69803491
# Point one:  (488, 309) Point two:  (960, 624)
# Coef:  -0.672731661765 Intercept:  631.232611468 intersection_x:  483.69803491
# Point one:  (478, 309) Point two:  (0, 631)
# Coef:  0.673518906033 Intercept:  -18.1996407734 intersection_x:  481.269664353
# Point one:  (486, 309) Point two:  (960, 628)
# Coef:  -0.678995573533 Intercept:  632.724548841 intersection_x:  481.269664353
# Point one:  (476, 309) Point two:  (0, 632)
# Coef:  0.681533508262 Intercept:  -26.0878635282 intersection_x:  482.355724939
# Point one:  (487, 306) Point two:  (960, 628)
# Coef:  -0.694221136654 Intercept:  637.515265558 intersection_x:  482.355724939
# Point one:  (477, 306) Point two:  (0, 637)
#  49%|████▉     | 109/222 [00:06<00:06, 18.71it/s]
#  50%|█████     | 111/222 [00:07<00:05, 18.81it/s]
#  51%|█████     | 113/222 [00:07<00:05, 18.97it/s]
# Coef:  0.666018377235 Intercept:  -15.4765438311 intersection_x:  481.672499629
# Point one:  (486, 308) Point two:  (960, 623)
# Coef:  -0.684619473665 Intercept:  635.088565905 intersection_x:  481.672499629
# Point one:  (476, 308) Point two:  (0, 635)
# Coef:  0.679125406164 Intercept:  -25.2678687355 intersection_x:  486.289328791
# Point one:  (491, 308) Point two:  (960, 626)
# Coef:  -0.658187030361 Intercept:  625.052898406 intersection_x:  486.289328791
# Point one:  (481, 308) Point two:  (0, 625)
# Coef:  0.670725034687 Intercept:  -20.7411013911 intersection_x:  485.904662479
# Point one:  (490, 308) Point two:  (960, 623)
# Coef:  -0.681281724477 Intercept:  636.205286589 intersection_x:  485.904662479
# Point one:  (480, 308) Point two:  (0, 636)
# Coef:  0.690160633974 Intercept:  -33.4751272994 intersection_x:  485.780267636
# Point one:  (490, 305) Point two:  (960, 629)
# Coef:  -0.692802114047 Intercept:  638.340886565 intersection_x:  485.780267636
# Point one:  (480, 305) Point two:  (0, 638)
#  52%|█████▏    | 115/222 [00:07<00:05, 19.02it/s]
# Coef:  0.67952748949 Intercept:  -27.592650069 intersection_x:  487.431220772
# Point one:  (492, 307) Point two:  (960, 624)
# Coef:  -0.663989006818 Intercept:  627.279235853 intersection_x:  487.431220772
# Point one:  (482, 306) Point two:  (0, 627)
# Coef:  0.669604487236 Intercept:  -22.2949228415 intersection_x:  485.191357708
# Point one:  (490, 305) Point two:  (960, 620)
# Coef:  -0.672929306858 Intercept:  629.090871484 intersection_x:  485.191357708
# Point one:  (480, 305) Point two:  (0, 629)
# Coef:  0.683226130984 Intercept:  -29.8196496235 intersection_x:  486.858518208
# Point one:  (491, 306) Point two:  (960, 626)
# Coef:  -0.656708456697 Intercept:  622.538918231 intersection_x:  486.858518208
# Point one:  (481, 306) Point two:  (0, 622)
# Coef:  0.652969427839 Intercept:  -9.92022674705 intersection_x:  481.548265035
# Point one:  (486, 307) Point two:  (960, 616)
# Coef:  -0.680882677861 Intercept:  632.393940566 intersection_x:  481.548265035
# Point one:  (476, 307) Point two:  (0, 632)
#  53%|█████▎    | 118/222 [00:07<00:05, 19.28it/s]
# Coef:  0.652034161975 Intercept:  -10.3779533535 intersection_x:  482.906957039
# Point one:  (487, 307) Point two:  (960, 615)
# Coef:  -0.67420818066 Intercept:  630.073700624 intersection_x:  482.906957039
# Point one:  (477, 307) Point two:  (0, 630)
# Coef:  0.658597877197 Intercept:  -14.8566212561 intersection_x:  486.012037726
# Point one:  (491, 308) Point two:  (960, 617)
# Coef:  -0.650668542424 Intercept:  621.46261927 intersection_x:  486.012037726
# Point one:  (481, 308) Point two:  (0, 621)
# Coef:  0.666735786114 Intercept:  -21.4145254001 intersection_x:  488.18646686
# Point one:  (493, 307) Point two:  (960, 618)
# Coef:  -0.660442340363 Intercept:  626.495875059 intersection_x:  488.18646686
# Point one:  (483, 307) Point two:  (0, 626)
# Coef:  0.655069204633 Intercept:  -11.4417820537 intersection_x:  482.852332653
# Point one:  (487, 308) Point two:  (960, 617)
# Coef:  -0.685007662047 Intercept:  635.617458957 intersection_x:  482.852332653
# Point one:  (477, 308) Point two:  (0, 635)
#  55%|█████▍    | 121/222 [00:07<00:05, 18.45it/s]
#  55%|█████▌    | 123/222 [00:07<00:05, 18.84it/s]
# Coef:  0.649818220764 Intercept:  -8.47480998029 intersection_x:  483.674881176
# Point one:  (488, 309) Point two:  (960, 615)
# Coef:  -0.689226309709 Intercept:  639.187394186 intersection_x:  483.674881176
# Point one:  (478, 309) Point two:  (0, 639)
# Coef:  0.65414717155 Intercept:  -12.6373290774 intersection_x:  483.370162658
# Point one:  (488, 306) Point two:  (960, 615)
# Coef:  -0.69265512937 Intercept:  638.366718186 intersection_x:  483.370162658
# Point one:  (478, 307) Point two:  (0, 638)
# Coef:  0.619154973275 Intercept:  14.9250468496 intersection_x:  479.878485475
# Point one:  (484, 315) Point two:  (960, 609)
# Coef:  -0.660740111464 Intercept:  629.119161682 intersection_x:  479.878485475
# Point one:  (474, 315) Point two:  (0, 629)
# Coef:  0.657208188262 Intercept:  -13.196781438 intersection_x:  485.131133906
# Point one:  (490, 308) Point two:  (960, 617)
# Coef:  -0.680450378864 Intercept:  635.743036011 intersection_x:  485.131133906
# Point one:  (480, 309) Point two:  (0, 635)
# Coef:  0.638386349445 Intercept:  -0.108322799036 intersection_x:  482.709518182
# Point one:  (487, 311) Point two:  (960, 612)
# Coef:  -0.669804093417 Intercept:  631.367655565 intersection_x:  482.709518182
# Point one:  (477, 311) Point two:  (0, 631)
#  57%|█████▋    | 126/222 [00:07<00:04, 19.88it/s]
#  58%|█████▊    | 129/222 [00:08<00:04, 20.52it/s]
# Coef:  0.664486286124 Intercept:  -17.9797983674 intersection_x:  486.401493386
# Point one:  (491, 308) Point two:  (960, 619)
# Coef:  -0.691442152078 Intercept:  641.545818899 intersection_x:  486.401493386
# Point one:  (481, 308) Point two:  (0, 641)
# Coef:  0.643450740822 Intercept:  -5.90836085696 intersection_x:  484.996650126
# Point one:  (489, 309) Point two:  (960, 611)
# Coef:  -0.681238117212 Intercept:  636.561297748 intersection_x:  484.996650126
# Point one:  (479, 309) Point two:  (0, 636)
# Coef:  0.641727262861 Intercept:  -3.30145702192 intersection_x:  483.465084427
# Point one:  (488, 310) Point two:  (960, 612)
# Coef:  -0.693056823521 Intercept:  642.020043992 intersection_x:  483.465084427
# Point one:  (478, 310) Point two:  (0, 642)
# Coef:  0.638250090275 Intercept:  -4.56207026243 intersection_x:  486.413874811
# Point one:  (491, 309) Point two:  (960, 608)
# Coef:  -0.684120691963 Intercept:  638.657425863 intersection_x:  486.413874811
# Point one:  (481, 309) Point two:  (0, 638)
# Coef:  0.611134757182 Intercept:  13.1309834894 intersection_x:  482.488630596
# Point one:  (487, 311) Point two:  (960, 599)
# Coef:  -0.70379130073 Intercept:  647.567856507 intersection_x:  482.488630596
# Point one:  (477, 311) Point two:  (0, 647)
#  59%|█████▉    | 132/222 [00:08<00:04, 20.54it/s]
#  61%|██████    | 135/222 [00:08<00:04, 21.35it/s]
# Coef:  0.634129420139 Intercept:  -0.415104506555 intersection_x:  483.238082577
# Point one:  (488, 309) Point two:  (960, 608)
# Coef:  -0.719562361509 Intercept:  653.740316458 intersection_x:  483.238082577
# Point one:  (478, 309) Point two:  (0, 653)
# Coef:  0.635610957964 Intercept:  -0.158873660506 intersection_x:  481.626433618
# Point one:  (486, 309) Point two:  (960, 610)
# Coef:  -0.723088891837 Intercept:  654.226889356 intersection_x:  481.626433618
# Point one:  (476, 309) Point two:  (0, 654)
# Coef:  0.637493488624 Intercept:  -2.38307287827 intersection_x:  484.62428907
# Point one:  (489, 309) Point two:  (960, 609)
# Coef:  -0.69444423024 Intercept:  643.106297211 intersection_x:  484.62428907
# Point one:  (479, 310) Point two:  (0, 643)
# Coef:  0.639318262212 Intercept:  -2.298660154 intersection_x:  482.230588375
# Point one:  (487, 309) Point two:  (960, 611)
# Coef:  -0.70402807125 Intercept:  645.504032623 intersection_x:  482.230588375
# Point one:  (477, 309) Point two:  (0, 645)
# Coef:  0.637770254054 Intercept:  -3.02632087901 intersection_x:  482.011852669
# Point one:  (487, 307) Point two:  (960, 609)
# Coef:  -0.69975147298 Intercept:  641.675004753 intersection_x:  482.011852669
# Point one:  (477, 307) Point two:  (0, 641)
#  62%|██████▏   | 138/222 [00:08<00:03, 22.80it/s]
#  64%|██████▎   | 141/222 [00:08<00:03, 24.17it/s]
# Coef:  0.636582452017 Intercept:  -7.41360752056 intersection_x:  486.867129517
# Point one:  (491, 305) Point two:  (960, 603)
# Coef:  -0.699360694296 Intercept:  643.013197323 intersection_x:  486.867129517
# Point one:  (481, 306) Point two:  (0, 643)
# Coef:  0.596535704949 Intercept:  19.9722881811 intersection_x:  479.24831919
# Point one:  (484, 308) Point two:  (960, 592)
# Coef:  -0.711136836137 Intercept:  646.672155547 intersection_x:  479.24831919
# Point one:  (474, 309) Point two:  (0, 646)
# Coef:  0.620094267867 Intercept:  7.91615465625 intersection_x:  480.690267058
# Point one:  (485, 309) Point two:  (960, 603)
# Coef:  -0.703161284855 Intercept:  643.99221968 intersection_x:  480.690267058
# Point one:  (475, 309) Point two:  (0, 643)
# Coef:  0.621707570356 Intercept:  3.4629096629 intersection_x:  484.719318154
# Point one:  (489, 307) Point two:  (960, 600)
# Coef:  -0.717468722904 Intercept:  652.587529419 intersection_x:  484.719318154
# Point one:  (479, 308) Point two:  (0, 652)
# Coef:  0.635757535148 Intercept:  -1.31869045589 intersection_x:  484.711759565
# Point one:  (489, 310) Point two:  (960, 609)
# Coef:  -0.702361477329 Intercept:  647.283330589 intersection_x:  484.711759565
# Point one:  (479, 310) Point two:  (0, 647)
# Coef:  0.639456929244 Intercept:  -3.67931805374 intersection_x:  484.631318204
# Point one:  (489, 309) Point two:  (960, 610)
# Coef:  -0.713411162711 Intercept:  651.962928707 intersection_x:  484.631318204
# Point one:  (479, 309) Point two:  (0, 651)
#  65%|██████▍   | 144/222 [00:08<00:03, 23.98it/s]
#  66%|██████▌   | 147/222 [00:08<00:03, 24.72it/s]
# Coef:  0.643206537112 Intercept:  -5.67148854106 intersection_x:  483.944876861
# Point one:  (488, 308) Point two:  (960, 611)
# Coef:  -0.725867598131 Intercept:  656.884925252 intersection_x:  483.944876861
# Point one:  (478, 309) Point two:  (0, 656)
# Coef:  0.634576743583 Intercept:  0.852921635987 intersection_x:  483.175274671
# Point one:  (488, 310) Point two:  (960, 610)
# Coef:  -0.709085908966 Intercept:  650.077492846 intersection_x:  483.175274671
# Point one:  (478, 311) Point two:  (0, 650)
# Coef:  0.629950792825 Intercept:  3.372268963 intersection_x:  481.739175694
# Point one:  (486, 309) Point two:  (960, 608)
# Coef:  -0.731492377425 Intercept:  659.232779553 intersection_x:  481.739175694
# Point one:  (476, 310) Point two:  (0, 659)
# Coef:  0.640336897006 Intercept:  -5.73539122135 intersection_x:  483.803508249
# Point one:  (488, 307) Point two:  (960, 608)
# Coef:  -0.736763740638 Intercept:  660.510728482 intersection_x:  483.803508249
# Point one:  (478, 307) Point two:  (0, 660)
# Coef:  0.595002728492 Intercept:  20.2937137214 intersection_x:  482.155068972
# Point one:  (487, 310) Point two:  (960, 591)
# Coef:  -0.707406633183 Intercept:  648.25698933 intersection_x:  482.155068972
# Point one:  (477, 310) Point two:  (0, 648)
# Coef:  0.629849381677 Intercept:  -3.27212940353 intersection_x:  487.146064926
# Point one:  (492, 306) Point two:  (960, 601)
# Coef:  -0.712130056179 Intercept:  650.467872959 intersection_x:
#  68%|██████▊   | 150/222 [00:08<00:02, 25.43it/s]
#  69%|██████▉   | 153/222 [00:08<00:02, 25.10it/s]
#  487.146064926
# Point one:  (482, 307) Point two:  (0, 650)
# Coef:  0.634110131982 Intercept:  -4.80990109741 intersection_x:  485.977937747
# Point one:  (490, 306) Point two:  (960, 603)
# Coef:  -0.718638085666 Intercept:  652.595888006 intersection_x:  485.977937747
# Point one:  (480, 306) Point two:  (0, 652)
# Coef:  0.627573386363 Intercept:  0.061674147451 intersection_x:  486.083016181
# Point one:  (491, 308) Point two:  (960, 602)
# Coef:  -0.703069053708 Intercept:  646.864364876 intersection_x:  486.083016181
# Point one:  (481, 308) Point two:  (0, 646)
# Coef:  0.62001461868 Intercept:  6.70253613136 intersection_x:  484.005220926
# Point one:  (489, 309) Point two:  (960, 601)
# Coef:  -0.703604595847 Intercept:  647.34114648 intersection_x:  484.005220926
# Point one:  (479, 310) Point two:  (0, 647)
# Coef:  0.623601835301 Intercept:  2.41139824946 intersection_x:  483.877630714
# Point one:  (488, 307) Point two:  (960, 601)
# Coef:  -0.746446924061 Intercept:  665.347345893 intersection_x:  483.877630714
# Point one:  (478, 307) Point two:  (0, 665)
# Coef:  0.617434053967 Intercept:  6.42757242372 intersection_x:  485.513875434
# Point one:  (490, 309) Point two:  (960, 599)
# Coef:  -0.706444173111 Intercept:  649.188821055 intersection_x:  485.513875434
# Point one:  (480, 309) Point two:  (0, 649)
#  70%|███████   | 156/222 [00:09<00:02, 25.40it/s]
# Coef:  0.628881112083 Intercept:  -2.8745163799 intersection_x:  488.043155779
# Point one:  (493, 307) Point two:  (960, 600)
# Coef:  -0.707734900522 Intercept:  649.451780478 intersection_x:  488.043155779
# Point one:  (483, 307) Point two:  (0, 649)
# Coef:  0.615082949621 Intercept:  6.59925403059 intersection_x:  486.240847768
# Point one:  (491, 308) Point two:  (960, 597)
# Coef:  -0.715544485991 Intercept:  653.604666386 intersection_x:  486.240847768
# Point one:  (481, 309) Point two:  (0, 653)
# Coef:  0.613850878793 Intercept:  4.08588761175 intersection_x:  486.720920398
# Point one:  (491, 305) Point two:  (960, 593)
# Coef:  -0.717514087839 Intercept:  652.089069557 intersection_x:  486.720920398
# Point one:  (481, 306) Point two:  (0, 652)
# Coef:  0.625358216828 Intercept:  -4.9198110899 intersection_x:  490.445312472
# Point one:  (495, 304) Point two:  (960, 595)
# Coef:  -0.721180394983 Intercept:  655.483739135 intersection_x:  490.445312472
# Point one:  (485, 305) Point two:  (0, 655)
# Coef:  0.624366758038 Intercept:  0.428217383601 intersection_x:  483.422467917
# Point one:  (488, 305) Point two:  (960, 599)
# Coef:  -0.755669106388 Intercept:  667.568560779 intersection_x:  483.422467917
# Point one:  (478, 306) Point two:  (0, 667)
# Coef:  0.623028168603 Intercept:  2.04715660038 intersection_x:  483.581383674
# Point one:  (488, 306) Point two:  (960, 600)
# Coef:  -0.737189900442 Intercept:  659.823292528 intersection_x:  483.581383674
# Point one:  (478, 307) Point two:  (0, 659)
#  72%|███████▏  | 159/222 [00:09<00:02, 26.16it/s]
#  73%|███████▎  | 162/222 [00:09<00:02, 26.90it/s]
#  74%|███████▍  | 165/222 [00:09<00:02, 27.24it/s]
# Coef:  0.612790550825 Intercept:  5.96317876567 intersection_x:  487.588064133
# Point one:  (492, 307) Point two:  (960, 594)
# Coef:  -0.725965028852 Intercept:  658.724420208 intersection_x:  487.588064133
# Point one:  (482, 308) Point two:  (0, 658)
# Coef:  0.622496451825 Intercept:  0.015687517538 intersection_x:  487.633716086
# Point one:  (492, 306) Point two:  (960, 597)
# Coef:  -0.735617630731 Intercept:  662.277904462 intersection_x:  487.633716086
# Point one:  (482, 307) Point two:  (0, 662)
# Coef:  0.610786576258 Intercept:  5.65885373256 intersection_x:  489.079128215
# Point one:  (494, 307) Point two:  (960, 592)
# Coef:  -0.738713946144 Intercept:  665.671392755 intersection_x:  489.079128215
# Point one:  (484, 308) Point two:  (0, 665)
# Coef:  0.614495984655 Intercept:  3.31222104771 intersection_x:  487.356967586
# Point one:  (492, 305) Point two:  (960, 593)
# Coef:  -0.765024805103 Intercept:  675.631289865 intersection_x:  487.356967586
# Point one:  (482, 306) Point two:  (0, 675)
# Coef:  0.603844709117 Intercept:  12.0895374104 intersection_x:  485.176450559
# Point one:  (490, 308) Point two:  (960, 591)
# Coef:  -0.753278364908 Intercept:  670.533693437 intersection_x:  485.176450559
# Point one:  (480, 308) Point two:  (0, 670)
# Coef:  0.588802843678 Intercept:  23.0243643458 intersection_x:  482.457271549
# Point one:  (487, 310) Point two:  (960, 588)
# Coef:  -0.764297065149 Intercept:  675.837254492 intersection_x:  482.457271549
# Point one:  (477, 310) Point two:  (0, 675)
#  76%|███████▌  | 168/222 [00:09<00:01, 27.41it/s]
# Coef:  0.598403179363 Intercept:  16.6729016444 intersection_x:  483.632001886
# Point one:  (488, 309) Point two:  (960, 591)
# Coef:  -0.760793374577 Intercept:  674.023851983 intersection_x:  483.632001886
# Point one:  (478, 309) Point two:  (0, 674)
# Coef:  0.585549426223 Intercept:  25.7484356506 intersection_x:  480.919933901
# Point one:  (485, 310) Point two:  (960, 587)
# Coef:  -0.784509189699 Intercept:  684.63693466 intersection_x:  480.919933901
# Point one:  (475, 311) Point two:  (0, 684)
# Coef:  0.587313432836 Intercept:  24.5276119403 intersection_x:  481.379777394
# Point one:  (486, 310) Point two:  (960, 588)
# Coef:  -0.783859888607 Intercept:  684.582720185 intersection_x:  481.379777394
# Point one:  (476, 311) Point two:  (0, 684)
# Coef:  0.59173354685 Intercept:  22.9333525038 intersection_x:  481.420894959
# Point one:  (486, 310) Point two:  (960, 590)
# Coef:  -0.786224787961 Intercept:  686.311287264 intersection_x:  481.420894959
# Point one:  (476, 311) Point two:  (0, 686)
# Coef:  0.592859406725 Intercept:  22.6080578099 intersection_x:  477.567929693
# Point one:  (482, 308) Point two:  (960, 591)
# Coef:  -0.79961453834 Intercept:  687.608956906 intersection_x:  477.567929693
# Point one:  (472, 309) Point two:  (0, 687)
# Coef:  0.598419555526 Intercept:  19.3304982998 intersection_x:  482.259409266
# Point one:  (487, 310) Point two:  (960, 593)
# Coef:  -0.773892248707 Intercept:  681.140778338 intersection_x:  482.259409266
# Point one:  (477, 311) Point two:  (0, 681)
#  77%|███████▋  | 171/222 [00:09<00:01, 27.05it/s]
#  78%|███████▊  | 174/222 [00:09<00:01, 27.12it/s]
# Coef:  0.59295659829 Intercept:  22.7794158846 intersection_x:  477.164650771
# Point one:  (482, 308) Point two:  (960, 592)
# Coef:  -0.82417942367 Intercept:  698.986630898 intersection_x:  477.164650771
# Point one:  (472, 309) Point two:  (0, 698)
# Coef:  0.590562111696 Intercept:  25.2789242037 intersection_x:  481.769070632
# Point one:  (486, 312) Point two:  (960, 592)
# Coef:  -0.759846433961 Intercept:  675.863994218 intersection_x:  481.769070632
# Point one:  (476, 313) Point two:  (0, 675)
# Coef:  0.588563292921 Intercept:  25.4476448823 intersection_x:  478.480405486
# Point one:  (483, 310) Point two:  (960, 590)
# Coef:  -0.811383594338 Intercept:  695.294799157 intersection_x:  478.480405486
# Point one:  (473, 311) Point two:  (0, 695)
# Coef:  0.592222984701 Intercept:  20.6737951021 intersection_x:  481.677009532
# Point one:  (486, 308) Point two:  (960, 589)
# Coef:  -0.780529264053 Intercept:  681.896993111 intersection_x:  481.677009532
# Point one:  (476, 309) Point two:  (0, 681)
# Coef:  0.593403788777 Intercept:  21.9213487185 intersection_x:  480.819536769
# Point one:  (485, 310) Point two:  (960, 591)
# Coef:  -0.780695230253 Intercept:  682.615002523 intersection_x:  480.819536769
# Point one:  (475, 311) Point two:  (0, 682)
# Coef:  0.592095981396 Intercept:  22.9850551019 intersection_x:  481.987813232
# Point one:  (486, 311) Point two:  (960, 591)
# Coef:  -0.789050580225 Intercept:  688.68086609 intersection_x:  481.987813232
# Point one:  (476, 312) Point two:  (0, 688)
#  80%|███████▉  | 177/222 [00:09<00:01, 26.95it/s]
#  81%|████████  | 180/222 [00:09<00:01, 26.07it/s]
# Coef:  0.589418863436 Intercept:  23.586426461 intersection_x:  480.741837649
# Point one:  (485, 309) Point two:  (960, 589)
# Coef:  -0.808041791379 Intercept:  695.404229698 intersection_x:  480.741837649
# Point one:  (475, 310) Point two:  (0, 695)
# Coef:  0.571484786338 Intercept:  32.2767667459 intersection_x:  479.071008703
# Point one:  (484, 308) Point two:  (960, 580)
# Coef:  -0.836820665298 Intercept:  706.955080023 intersection_x:  479.071008703
# Point one:  (474, 310) Point two:  (0, 706)
# Coef:  0.592813165182 Intercept:  20.39601435 intersection_x:  481.170693503
# Point one:  (486, 308) Point two:  (960, 589)
# Coef:  -0.809603039967 Intercept:  695.197592361 intersection_x:  481.170693503
# Point one:  (476, 309) Point two:  (0, 695)
# Coef:  0.58963072729 Intercept:  21.3977085379 intersection_x:  481.53745175
# Point one:  (486, 308) Point two:  (960, 587)
# Coef:  -0.809048146543 Intercept:  694.91396926 intersection_x:  481.53745175
# Point one:  (476, 309) Point two:  (0, 694)
# Coef:  0.581506302489 Intercept:  26.4644505097 intersection_x:  480.050905394
# Point one:  (485, 308) Point two:  (960, 584)
# Coef:  -0.816131395062 Intercept:  697.401692632 intersection_x:  480.050905394
# Point one:  (475, 309) Point two:  (0, 697)
#  82%|████████▏ | 183/222 [00:10<00:01, 23.65it/s]
#  84%|████████▍ | 186/222 [00:10<00:01, 23.89it/s]
# Coef:  0.57814680108 Intercept:  28.3094998027 intersection_x:  481.208621915
# Point one:  (486, 309) Point two:  (960, 583)
# Coef:  -0.810276037909 Intercept:  696.430540788 intersection_x:  481.208621915
# Point one:  (476, 310) Point two:  (0, 696)
# Coef:  0.578320345217 Intercept:  28.2714826873 intersection_x:  481.093436908
# Point one:  (486, 309) Point two:  (960, 583)
# Coef:  -0.811527014652 Intercept:  696.917925824 intersection_x:  481.093436908
# Point one:  (476, 310) Point two:  (0, 696)
# Coef:  0.588368633289 Intercept:  21.8164824236 intersection_x:  481.655556745
# Point one:  (486, 308) Point two:  (960, 586)
# Coef:  -0.79313847403 Intercept:  687.227057347 intersection_x:  481.655556745
# Point one:  (476, 309) Point two:  (0, 687)
# Coef:  0.570104171289 Intercept:  34.7026807907 intersection_x:  479.949992661
# Point one:  (484, 311) Point two:  (960, 582)
# Coef:  -0.760224780702 Intercept:  673.194051535 intersection_x:  479.949992661
# Point one:  (474, 312) Point two:  (0, 673)
# Coef:  0.590185286762 Intercept:  21.1628253648 intersection_x:  481.680968589
# Point one:  (486, 308) Point two:  (960, 587)
# Coef:  -0.780193439865 Intercept:  681.24817774 intersection_x:  481.680968589
# Point one:  (476, 309) Point two:  (0, 681)
#  85%|████████▌ | 189/222 [00:10<00:01, 24.25it/s]
#  86%|████████▋ | 192/222 [00:10<00:01, 23.95it/s]
# Coef:  0.584211815547 Intercept:  22.0277986633 intersection_x:  482.205799569
# Point one:  (487, 306) Point two:  (960, 582)
# Coef:  -0.79955469624 Intercept:  689.288035897 intersection_x:  482.205799569
# Point one:  (477, 307) Point two:  (0, 689)
# Coef:  0.584928838641 Intercept:  19.0732386089 intersection_x:  483.829870732
# Point one:  (488, 305) Point two:  (960, 580)
# Coef:  -0.77112330113 Intercept:  675.1717701 intersection_x:  483.829870732
# Point one:  (478, 305) Point two:  (0, 675)
# Coef:  0.585291902402 Intercept:  16.284929126 intersection_x:  485.315956085
# Point one:  (490, 303) Point two:  (960, 578)
# Coef:  -0.760198223434 Intercept:  669.272755949 intersection_x:  485.315956085
# Point one:  (480, 304) Point two:  (0, 669)
# Coef:  0.571552869669 Intercept:  28.4079614269 intersection_x:  478.590077276
# Point one:  (483, 304) Point two:  (960, 577)
# Coef:  -0.821351619272 Intercept:  695.038228427 intersection_x:  478.590077276
# Point one:  (473, 306) Point two:  (0, 695)
# Coef:  0.561847187041 Intercept:  35.430324921 intersection_x:  478.917496411
# Point one:  (483, 307) Point two:  (960, 574)
# Coef:  -0.802732941904 Intercept:  688.951623928 intersection_x:  478.917496411
# Point one:  (473, 308) Point two:  (0, 688)
# Coef:  0.58600504604 Intercept:  20.4856776223 intersection_x:  483.600571865
# Point one:  (488, 306) Point two:  (960, 583)
# Coef:  -0.796297904718 Intercept:  688.968175099 intersection_x:  483.600571865
# Point one:  (478, 307) Point two:  (0, 688)
# Coef:  0.5833834012 Intercept:  24.6917140356 intersection_x:  483.23138732
# Point one:  (488, 309) Point two:  (960, 584)
# Coef:  -0.78031471611 Intercept:  683.673447149 intersection_x:  483.23138732
# Point one:  (478, 310) Point two:  (0, 683)
#  88%|████████▊ | 195/222 [00:11<00:02, 10.89it/s]
#  89%|████████▉ | 198/222 [00:11<00:01, 12.87it/s]
# Coef:  0.586968485691 Intercept:  22.1704176805 intersection_x:  483.905439404
# Point one:  (488, 309) Point two:  (960, 585)
# Coef:  -0.779691155118 Intercept:  683.504451682 intersection_x:  483.905439404
# Point one:  (478, 310) Point two:  (0, 683)
# Coef:  0.583739861835 Intercept:  24.6655074468 intersection_x:  484.035762449
# Point one:  (489, 310) Point two:  (960, 585)
# Coef:  -0.776616781369 Intercept:  683.126772442 intersection_x:  484.035762449
# Point one:  (479, 311) Point two:  (0, 683)
# Coef:  0.586379447993 Intercept:  23.2804516423 intersection_x:  479.660149412
# Point one:  (484, 307) Point two:  (960, 586)
# Coef:  -0.814659096937 Intercept:  695.302809435 intersection_x:  479.660149412
# Point one:  (474, 308) Point two:  (0, 695)
# Coef:  0.584647363903 Intercept:  22.3800821744 intersection_x:  483.391750397
# Point one:  (488, 307) Point two:  (960, 583)
# Coef:  -0.776782585736 Intercept:  680.484088573 intersection_x:  483.391750397
# Point one:  (478, 308) Point two:  (0, 680)
# Coef:  0.587297458291 Intercept:  21.2095712106 intersection_x:  481.090805069
# Point one:  (486, 306) Point two:  (960, 585)
# Coef:  -0.817888269949 Intercept:  697.231504482 intersection_x:  481.090805069
# Point one:  (476, 307) Point two:  (0, 697)
#  90%|█████████ | 200/222 [00:11<00:01, 14.26it/s]
#  91%|█████████▏| 203/222 [00:11<00:01, 15.76it/s]
# Coef:  0.58612293064 Intercept:  23.2302712464 intersection_x:  482.086871005
# Point one:  (487, 308) Point two:  (960, 585)
# Coef:  -0.782476305707 Intercept:  683.013994757 intersection_x:  482.086871005
# Point one:  (477, 309) Point two:  (0, 683)
# Coef:  0.560970598968 Intercept:  40.6965658082 intersection_x:  476.963058893
# Point one:  (481, 311) Point two:  (960, 579)
# Coef:  -0.792604308831 Intercept:  686.301794272 intersection_x:  476.963058893
# Point one:  (471, 312) Point two:  (0, 686)
# Coef:  0.585308977092 Intercept:  22.2027285969 intersection_x:  480.933934067
# Point one:  (485, 306) Point two:  (960, 584)
# Coef:  -0.820416162618 Intercept:  698.263650255 intersection_x:  480.933934067
# Point one:  (475, 307) Point two:  (0, 698)
# Coef:  0.588222015595 Intercept:  19.2035996623 intersection_x:  484.815143191
# Point one:  (489, 307) Point two:  (960, 583)
# Coef:  -0.780051406001 Intercept:  682.563274478 intersection_x:  484.815143191
# Point one:  (479, 308) Point two:  (0, 682)
# Coef:  0.57576835079 Intercept:  27.5619214266 intersection_x:  481.984278535
# Point one:  (486, 307) Point two:  (960, 580)
# Coef:  -0.778533137017 Intercept:  680.313946947 intersection_x:  481.984278535
# Point one:  (476, 308) Point two:  (0, 680)
#  93%|█████████▎| 206/222 [00:11<00:00, 17.28it/s]
# Coef:  0.559502757216 Intercept:  39.0064630677 intersection_x:  478.906931879
# Point one:  (483, 309) Point two:  (960, 576)
# Coef:  -0.792525953984 Intercept:  686.502384961 intersection_x:  478.906931879
# Point one:  (473, 310) Point two:  (0, 686)
# Coef:  0.557233853388 Intercept:  37.9928369505 intersection_x:  480.443240286
# Point one:  (485, 308) Point two:  (960, 572)
# Coef:  -0.785923854513 Intercept:  683.30387835 intersection_x:  480.443240286
# Point one:  (475, 309) Point two:  (0, 683)
# Coef:  0.568127915765 Intercept:  32.1437559672 intersection_x:  479.182562169
# Point one:  (484, 307) Point two:  (960, 577)
# Coef:  -0.79828340644 Intercept:  686.904234318 intersection_x:  479.182562169
# Point one:  (474, 308) Point two:  (0, 686)
# Coef:  0.564135719949 Intercept:  34.2860818878 intersection_x:  477.622023694
# Point one:  (482, 306) Point two:  (960, 575)
# Coef:  -0.799207118248 Intercept:  685.448647256 intersection_x:  477.622023694
# Point one:  (472, 307) Point two:  (0, 685)
# Coef:  0.563965744401 Intercept:  33.0924901186 intersection_x:  481.829788567
# Point one:  (486, 307) Point two:  (960, 574)
# Coef:  -0.764066146585 Intercept:  672.977815362 intersection_x:  481.829788567
# Point one:  (476, 308) Point two:  (0, 672)
#  94%|█████████▍| 209/222 [00:11<00:00, 17.82it/s]
#  95%|█████████▌| 212/222 [00:11<00:00, 18.44it/s]
# Coef:  0.563966158185 Intercept:  33.3849506474 intersection_x:  481.930762462
# Point one:  (486, 307) Point two:  (960, 574)
# Coef:  -0.767930162634 Intercept:  675.26676006 intersection_x:  481.930762462
# Point one:  (476, 309) Point two:  (0, 675)
# Coef:  0.568655191088 Intercept:  30.4544406237 intersection_x:  483.637823939
# Point one:  (488, 308) Point two:  (960, 576)
# Coef:  -0.744751021925 Intercept:  665.667363434 intersection_x:  483.637823939
# Point one:  (478, 309) Point two:  (0, 665)
# Coef:  0.562265441661 Intercept:  35.2674016293 intersection_x:  483.443586618
# Point one:  (488, 309) Point two:  (960, 575)
# Coef:  -0.739424367084 Intercept:  664.560991433 intersection_x:  483.443586618
# Point one:  (478, 310) Point two:  (0, 664)
# Coef:  0.568200166748 Intercept:  33.5521602159 intersection_x:  481.440119469
# Point one:  (486, 309) Point two:  (960, 579)
# Coef:  -0.761951566952 Intercept:  673.940569801 intersection_x:  481.440119469
# Point one:  (476, 310) Point two:  (0, 673)
# Coef:  0.560252023137 Intercept:  41.3540619101 intersection_x:  479.545632403
# Point one:  (484, 312) Point two:  (960, 579)
# Coef:  -0.76594512777 Intercept:  677.326113333 intersection_x:  479.545632403
# Point one:  (474, 313) Point two:  (0, 677)
#  97%|█████████▋| 215/222 [00:12<00:00, 19.65it/s]
#  98%|█████████▊| 218/222 [00:12<00:00, 21.10it/s]
# Coef:  0.570322376547 Intercept:  33.5748981675 intersection_x:  480.904083737
# Point one:  (485, 310) Point two:  (960, 581)
# Coef:  -0.771618436385 Intercept:  678.919715239 intersection_x:  480.904083737
# Point one:  (475, 311) Point two:  (0, 678)
# Coef:  0.56900408874 Intercept:  35.025999414 intersection_x:  479.528364859
# Point one:  (484, 310) Point two:  (960, 581)
# Coef:  -0.782267058363 Intercept:  682.998843066 intersection_x:  479.528364859
# Point one:  (474, 311) Point two:  (0, 682)
# Coef:  0.566557474687 Intercept:  36.375 intersection_x:  480.270083625
# Point one:  (485, 311) Point two:  (960, 580)
# Coef:  -0.77498264212 Intercept:  680.676584085 intersection_x:  480.270083625
# Point one:  (475, 312) Point two:  (0, 680)
# Coef:  0.562916466427 Intercept:  39.2774007607 intersection_x:  478.599966114
# Point one:  (483, 311) Point two:  (960, 579)
# Coef:  -0.783359410788 Intercept:  683.604989975 intersection_x:  478.599966114
# Point one:  (473, 312) Point two:  (0, 683)
# Coef:  0.564950402503 Intercept:  38.2941256341 intersection_x:  477.88253257
# Point one:  (482, 311) Point two:  (960, 580)
# Coef:  -0.781881039241 Intercept:  681.92134596 intersection_x:  477.88253257
# Point one:  (472, 312) Point two:  (0, 681)
# 100%|█████████▉| 221/222 [00:12<00:00, 19.29it/s]
# Coef:  0.56752694859 Intercept:  36.3459266169 intersection_x:  478.386159657
# Point one:  (483, 310) Point two:  (960, 581)
# Coef:  -0.781348933889 Intercept:  681.62947989 intersection_x:  478.386159657
# Point one:  (473, 311) Point two:  (0, 681)
# Coef:  0.564327347568 Intercept:  40.5752326369 intersection_x:  476.755277848
# Point one:  (481, 312) Point two:  (960, 582)
# Coef:  -0.783456634822 Intercept:  683.138359641 intersection_x:  476.755277848
# Point one:  (471, 313) Point two:  (0, 683)
# [MoviePy] Done.
# [MoviePy] >>>> Video ready: solidWhiteRight.mp4
#
# CPU times: user 9.44 s, sys: 1.08 s, total: 10.5 s
# Wall time: 13.3 s

# %% [markdown]
# Play the video inline, or if you prefer find the video in your filesystem (should be in the same directory) and play it in your video player of choice.

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(white_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="solidWhiteRight.mp4">
# </video>

# %% [markdown]
# ## Improve the draw_lines() function
#
# **At this point, if you were successful with making the pipeline and tuning parameters, you probably have the Hough line segments drawn onto the road, but what about identifying the full extent of the lane and marking it clearly as in the example video (P1_example.mp4)?  Think about defining a line to run the full length of the visible lane based on the line segments you identified with the Hough Transform. As mentioned previously, try to average and/or extrapolate the line segments you've detected to map out the full extent of the lane lines. You can see an example of the result you're going for in the video "P1_example.mp4".**
#
# **Go back and modify your draw_lines function accordingly and try re-running your pipeline. The new output should draw a single, solid line over the left lane line and a single, solid line over the right lane line. The lines should start from the bottom of the image and extend out to the top of the region of interest.**

# %% [markdown]
# Now for the one with the solid yellow lane on the left. This one's more tricky!

# %%
yellow_output = 'solidYellowLeft.mp4'
## To speed up the testing process you may want to try your pipeline on a shorter subclip of the video
## To do so add .subclip(start_second,end_second) to the end of the line below
## Where start_second and end_second are integer values representing the start and end of the subclip
## You may also uncomment the following line for a subclip of the first 5 seconds
##clip2 = VideoFileClip('test_videos/solidYellowLeft.mp4').subclip(0,5)
clip2 = VideoFileClip('test_videos/solidYellowLeft.mp4')
yellow_clip = clip2.fl_image(process_image)
# %time yellow_clip.write_videofile(yellow_output, audio=False)
# Out:
# Coef:  0.649270699049 Intercept:  -6.96844560913 intersection_x:  487.522904684
# Point one:  (492, 312) Point two:  (960, 616)
# Coef:  -0.610822776738 Intercept:  607.355985879 intersection_x:  487.522904684
# Point one:  (482, 312) Point two:  (0, 607)
# [MoviePy] >>>> Building video solidYellowLeft.mp4
# [MoviePy] Writing video solidYellowLeft.mp4
#   0%|          | 0/682 [00:00<?, ?it/s]
# Coef:  0.649270699049 Intercept:  -6.96844560913 intersection_x:  487.522904684
# Point one:  (492, 312) Point two:  (960, 616)
# Coef:  -0.610822776738 Intercept:  607.355985879 intersection_x:  487.522904684
# Point one:  (482, 312) Point two:  (0, 607)
#   0%|          | 2/682 [00:00<00:42, 16.09it/s]
# Coef:  0.673457132299 Intercept:  -19.3501940133 intersection_x:  488.657268451
# Point one:  (493, 313) Point two:  (960, 627)
# Coef:  -0.617816188002 Intercept:  611.639899508 intersection_x:  488.657268451
# Point one:  (483, 312) Point two:  (0, 611)
# Coef:  0.676009703645 Intercept:  -21.8308090742 intersection_x:  487.427640137
# Point one:  (492, 311) Point two:  (960, 627)
# Coef:  -0.63106445369 Intercept:  615.27326292 intersection_x:  487.427640137
# Point one:  (482, 310) Point two:  (0, 615)
# Coef:  0.688952745849 Intercept:  -30.4444444444 intersection_x:  491.301341998
# Point one:  (496, 311) Point two:  (960, 630)
# Coef:  -0.615066240613 Intercept:  610.221833596 intersection_x:  491.301341998
# Point one:  (486, 311) Point two:  (0, 610)
#   1%|          | 4/682 [00:00<00:41, 16.44it/s]
# Coef:  0.646145827233 Intercept:  -3.22245421099 intersection_x:  482.786352598
# Point one:  (487, 311) Point two:  (960, 617)
# Coef:  -0.634231717216 Intercept:  614.926350422 intersection_x:  482.786352598
# Point one:  (477, 311) Point two:  (0, 614)
# Coef:  0.647580645161 Intercept:  -5.99516129032 intersection_x:  486.323595462
# Point one:  (491, 312)
#   1%|          | 6/682 [00:00<00:45, 14.92it/s]
#  Point two:  (960, 615)
# Coef:  -0.63341024227 Intercept:  616.980932839 intersection_x:  486.323595462
# Point one:  (481, 312) Point two:  (0, 616)
# Coef:  0.675039872408 Intercept:  -23.0964912281 intersection_x:  487.919877312
# Point one:  (492, 309) Point two:  (960, 624)
# Coef:  -0.685937219716 Intercept:  640.951284586 intersection_x:  487.919877312
# Point one:  (482, 309) Point two:  (0, 640)
#   1%|          | 8/682 [00:00<00:43, 15.43it/s]
# Coef:  0.665098327425 Intercept:  -17.8934538048 intersection_x:  489.262153598
# Point one:  (494, 310) Point two:  (960, 620)
# Coef:  -0.647364025506 Intercept:  624.244703506 intersection_x:  489.262153598
# Point one:  (484, 310) Point two:  (0, 624)
# Coef:  0.67292358804 Intercept:  -23.7622923588 intersection_x:  491.262788527
# Point one:  (496, 310) Point two:  (960, 622)
# Coef:  -0.649050102714 Intercept:  625.674189321 intersection_x:  491.262788527
# Point one:  (486, 310) Point two:  (0, 625)
# Coef:  0.658596087457 Intercept:  -15.7354890679 intersection_x:  489.205830089
# Point one:  (494, 309) Point two:  (960, 616)
# Coef:  -0.65121148513 Intercept:  625.030011736 intersection_x:  489.205830089
# Point one:  (484, 309) Point two:  (0, 625)
#   1%|▏         | 10/682 [00:00<00:50, 13.25it/s]
# Coef:  0.658343054175 Intercept:  -14.6162151203 intersection_x:  489.156871243
# Point one:  (494, 310) Point two:  (960, 617)
# Coef:
#   2%|▏         | 12/682 [00:00<00:52, 12.81it/s]
#  -0.646647543059 Intercept:  623.728902424 intersection_x:  489.156871243
# Point one:  (484, 310) Point two:  (0, 623)
# Coef:  0.662927350427 Intercept:  -19.718482906 intersection_x:  487.685661033
# Point one:  (492, 306) Point two:  (960, 616)
# Coef:  -0.669659161165 Intercept:  630.164850883 intersection_x:  487.685661033
# Point one:  (482, 306) Point two:  (0, 630)
# Coef:  0.664142049212 Intercept:  -19.5497378852 intersection_x:  488.944823104
# Point one:  (493, 308) Point two:  (960, 618)
# Coef:  -0.65884561844 Intercept:  627.318233244 intersection_x:  488.944823104
# Point one:  (483, 308) Point two:  (0, 627)
# Coef:  0.648356605901 Intercept:  -9.1685192414 intersection_x:  487.188370677
# Point one:  (492, 309) Point two:  (960, 613)
# Coef:  -0.664401269629 Intercept:  630.391851231 intersection_x:  487.188370677
# Point one:  (482, 310) Point two:  (0, 630)
#   2%|▏         | 16/682 [00:01<00:46, 14.46it/s]
# Coef:  0.624713034266 Intercept:  5.25277996739 intersection_x:  484.802524738
# Point one:  (489, 311) Point two:  (960, 604)
# Coef:  -0.679071464366 Intercept:  637.330796618 intersection_x:  484.802524738
# Point one:  (479, 311) Point two:  (0, 637)
# Coef:  0.617684137845 Intercept:  10.4752439914 intersection_x:  481.926180219
# Point one:  (486, 311) Point two:  (960, 603)
# Coef:  -0.6821494497 Intercept:  636.899079757 intersection_x:  481.926180219
# Point one:  (476, 311) Point two:  (0, 636)
# Coef:  0.625990923693 Intercept:  5.15937616172 intersection_x:  481.924869166
# Point one:  (486, 309) Point two:  (960, 606)
# Coef:  -0.682660484046 Intercept:  635.83103462 intersection_x:  481.924869166
# Point one:  (476, 310) Point two:  (0, 635)
#   3%|▎         | 18/682 [00:01<00:42, 15.67it/s]
# Coef:  0.608217168012 Intercept:  14.6834189288 intersection_x:  481.552574565
# Point one:  (486, 310) Point two:  (960, 598)
# Coef:  -0.690680124923 Intercept:  640.170754436 intersection_x:  481.552574565
# Point one:  (476, 311) Point two:  (0, 640)
# Coef:  0.606821106821 Intercept:  15.7631917632 intersection_x:  481.559838086
# Point one:  (486, 311) Point two:  (960, 598)
# Coef:  -0.687930728745 Intercept:  639.26367606 intersection_x:  481.559838086
# Point one:  (476, 311) Point two:  (0, 639)
#   3%|▎         | 20/682 [00:01<00:41, 16.13it/s]
# Coef:  0.608733545711 Intercept:  14.2713229549 intersection_x:  482.837562191
# Point one:  (487, 311) Point two:  (960, 598)
# Coef:  -0.686160740333 Intercept:  639.494923324 intersection_x:  482.837562191
# Point one:  (477, 311) Point two:  (0, 639)
# Coef:  0.627906976744 Intercept:  -1.53488372093 intersection_x:  486.708799811
# Point one:  (491, 307) Point two:  (960, 601)
# Coef:  -0.683349213161 Intercept:  636.665042713 intersection_x:  486.708799811
# Point one:  (481, 307) Point two:  (0, 636)
#   3%|▎         | 22/682 [00:01<00:39, 16.51it/s]
# Coef:  0.63112244898 Intercept:  -1.14540816327 intersection_x:  485.642524775
# Point one:  (490, 308) Point two:  (960, 604)
# Coef:  -0.667870110776 Intercept:  629.70061822 intersection_x:  485.642524775
# Point one:  (480, 308) Point two:  (0, 629)
# Coef:  0.636441798942 Intercept:  -5.56567460317 intersection_x:  484.011991448
# Point one:  (489, 305) Point two:  (960, 605)
# Coef:  -0.686296463147 Intercept:  634.655505795 intersection_x:  484.011991448
# Point one:  (479, 305) Point two:  (0, 634)
#   4%|▎         | 25/682 [00:01<00:35, 18.59it/s]
# Coef:  0.626086956522 Intercept:  2.92608695652 intersection_x:  481.637649488
# Point one:  (486, 307) Point two:  (960, 603)
# Coef:  -0.681497765077 Intercept:  632.708118774 intersection_x:  481.637649488
# Point one:  (476, 307) Point two:  (0, 632)
# Coef:  0.635433830326 Intercept:  -3.44397781618 intersection_x:  483.953861319
# Point one:  (488, 307) Point two:  (960, 606)
# Coef:  -0.688734955123 Intercept:  637.392618941 intersection_x:  483.953861319
# Point one:  (478, 307) Point two:  (0, 637)
# Coef:  0.622505561471 Intercept:  5.87698368032 intersection_x:  482.38151755
# Point one:  (487, 309) Point two:  (960, 603)
# Coef:  -0.700094246096 Intercept:  643.874685965 intersection_x:  482.38151755
# Point one:  (477, 309) Point two:  (0, 643)
#   4%|▍         | 28/682 [00:01<00:33, 19.42it/s]
# Coef:  0.614358711135 Intercept:  10.1072886669 intersection_x:  484.418188017
# Point one:  (489, 310) Point two:  (960, 599)
# Coef:  -0.704172163203 Intercept:  648.827625658 intersection_x:  484.418188017
# Point one:  (479, 311) Point two:  (0, 648)
# Coef:  0.618793631679 Intercept:  5.29235798425 intersection_x:  483.768948489
# Point one:  (488, 307) Point two:  (960, 599)
# Coef:  -0.72227156497 Intercept:  654.058058022 intersection_x:  483.768948489
# Point one:  (478, 308) Point two:  (0, 654)
# Coef:  0.604797412326 Intercept:  14.8641215526 intersection_x:  479.648715586
# Point one:  (484, 307) Point two:  (960, 595)
# Coef:  -0.713900100676 Intercept:  647.37568991 intersection_x:  479.648715586
# Point one:  (474, 308) Point two:  (0, 647)
# Coef:  0.551020408163 Intercept:  54.2040816327 intersection_x:  470.942143892
# Point one:  (475, 316) Point two:  (960, 583)
# Coef:  -0.723476915074 Intercept:  654.418583423 intersection_x:  470.942143892
# Point one:  (465, 317) Point two:  (0, 654)
# Coef:  0.618556701031 Intercept:  5.9587628866 intersection_x:  483.842489657
# Point one:  (488, 308) Point two:  (960, 599)
# Coef:  -0.701714325503 Intercept:  644.761983386 intersection_x:  483.842489657
# Point one:  (478, 308) Point two:  (0, 644)
#   5%|▍         | 31/682 [00:01<00:31, 20.36it/s]
# Coef:  0.611965811966 Intercept:  10.3324786325 intersection_x:  479.780496097
# Point one:  (484, 307) Point two:  (960, 597)
# Coef:  -0.734100431025 Intercept:  656.148808474 intersection_x:  479.780496097
# Point one:  (474, 307) Point two:  (0, 656)
# Coef:  0.622377622378 Intercept:  3.21678321678 intersection_x:  483.543330058
# Point one:  (488, 307) Point two:  (960, 600)
# Coef:  -0.701593297361 Intercept:  643.414090648 intersection_x:  483.543330058
# Point one:  (478, 307) Point two:  (0, 643)
#   5%|▍         | 34/682 [00:01<00:29, 21.67it/s]
# Coef:  0.608695652174 Intercept:  12.0434782609 intersection_x:  478.826212093
# Point one:  (483, 306) Point two:  (960, 596)
# Coef:  -0.756965342713 Intercept:  665.957759446 intersection_x:  478.826212093
# Point one:  (473, 307) Point two:  (0, 665)
# Coef:  0.61037037037 Intercept:  7.34814814815 intersection_x:  481.835446264
# Point one:  (486, 304) Point two:  (960, 593)
# Coef:  -0.754304093719 Intercept:  664.896677557 intersection_x:  481.835446264
# Point one:  (476, 305) Point two:  (0, 664)
# Coef:  0.60346695558 Intercept:  13.0092091008 intersection_x:  479.798603675
# Point one:  (484, 305) Point two:  (960, 592)
# Coef:  -0.731274463485 Intercept:  653.416278235 intersection_x:  479.798603675
# Point one:  (474, 306) Point two:  (0, 653)
# Coef:  0.600748337029 Intercept:  14.5734478936 intersection_x:  480.279332
#   5%|▌         | 37/682 [00:02<00:28, 22.64it/s]
# Point one:  (485, 306) Point two:  (960, 591)
# Coef:  -0.730869968926 Intercept:  654.122198356 intersection_x:  480.279332
# Point one:  (475, 306) Point two:  (0, 654)
# Coef:  0.61851696237 Intercept:  2.77068964884 intersection_x:  480.898959407
# Point one:  (485, 303) Point two:  (960, 596)
# Coef:  -0.733852779026 Intercept:  653.123891019 intersection_x:  480.898959407
# Point one:  (475, 303) Point two:  (0, 653)
# Coef:  0.589053302812 Intercept:  22.6922743623 intersection_x:  476.127127617
# Point one:  (481, 306) Point two:  (960, 588)
# Coef:  -0.737968834844 Intercept:  654.523513049 intersection_x:  476.127127617
# Point one:  (471, 306)
#   6%|▌         | 40/682 [00:02<00:26, 23.95it/s]
#  Point two:  (0, 654)
# Coef:  0.599413760508 Intercept:  14.7786549837 intersection_x:  478.679162595
# Point one:  (483, 304) Point two:  (960, 590)
# Coef:  -0.730176993471 Intercept:  651.226043692 intersection_x:  478.679162595
# Point one:  (473, 305) Point two:  (0, 651)
# Coef:  0.599059907834 Intercept:  15.274359447 intersection_x:  477.793459413
# Point one:  (482, 304) Point two:  (960, 590)
# Coef:  -0.731385827289 Intercept:  650.952629793 intersection_x:  477.793459413
# Point one:  (472, 305) Point two:  (0, 650)
# Coef:  0.595586989953 Intercept:  17.1288945796 intersection_x:  477.603672804
# Point one:  (482, 304) Point two:  (960, 588)
# Coef:  -0.732135354373 Intercept:  651.253962693 intersection_x:  477.603672804
# Point one:  (472, 305) Point two:  (0, 651)
#   6%|▋         | 43/682 [00:02<00:27, 23.33it/s]
# Coef:  0.571428571429 Intercept:  33.4285714286 intersection_x:  473.443505838
# Point one:  (478, 306) Point two:  (960, 582)
# Coef:  -0.743724228756 Intercept:  656.079123861 intersection_x:  473.443505838
# Point one:  (468, 307) Point two:  (0, 656)
# Coef:  0.603773584906 Intercept:  14.9433962264 intersection_x:  475.949532045
# Point one:  (480, 305) Point two:  (960, 594)
# Coef:  -0.74209024809 Intercept:  655.506657737 intersection_x:  475.949532045
# Point one:  (470, 306) Point two:  (0, 655)
#   7%|▋         | 46/682 [00:02<00:26, 24.15it/s]
# Coef:  0.577235772358 Intercept:  33.0 intersection_x:  474.202840004
# Point one:  (479, 309) Point two:  (960, 587)
# Coef:  -0.727969307455 Intercept:  651.931955635 intersection_x:  474.202840004
# Point one:  (469, 310) Point two:  (0, 651)
# Coef:  0.6 Intercept:  19.2 intersection_x:  473.567362314
# Point one:  (478, 306) Point two:  (960, 595)
# Coef:  -0.755411371918 Intercept:  661.07858825 intersection_x:  473.567362314
# Point one:  (468, 307) Point two:  (0, 661)
# Coef:  0.609088319088 Intercept:  11.9637606838 intersection_x:  478.14493507
# Point one:  (483, 306) Point two:  (960, 596)
# Coef:  -0.730010197521 Intercept:  652.24693396 intersection_x:  478.14493507
# Point one:  (473, 306) Point two:  (0, 652)
#   7%|▋         | 49/682 [00:02<00:26, 23.72it/s]
# Coef:  0.611363636364 Intercept:  10.4371212121 intersection_x:  477.570909632
# Point one:  (482, 305) Point two:  (960, 597)
# Coef:  -0.739095056588 Intercept:  655.376907625 intersection_x:  477.570909632
# Point one:  (472, 306) Point two:  (0, 655)
# Coef:  0.599363329482 Intercept:  17.5293042791 intersection_x:  477.557685449
# Point one:  (482, 306) Point two:  (960, 592)
# Coef:  -0.723363474124 Intercept:  649.207655091 intersection_x:  477.557685449
# Point one:  (472, 307) Point two:  (0, 649)
# Coef:  0.633945578231 Intercept:  -5.84925170068 intersection_x:  479.997149409
# Point one:  (484, 301) Point two:  (960, 602)
# Coef:  -0.738042691456 Intercept:  652.701206771 intersection_x:  479.997149409
# Point one:  (474, 302) Point two:  (0, 652)
# Coef:  0.610851946772 Intercept:  10.8686372755 intersection_x:  477.739860684
# Point one:  (482, 305) Point two:  (960, 597)
# Coef:  -0.730475220775 Intercept:  651.674091431 intersection_x:  477.739860684
# Point one:  (472, 306) Point two:  (0, 651)
# Coef:  0.599238140654 Intercept:  16.4656754547 intersection_x:  477.87910004
# Point one:  (482, 305) Point two:  (960, 591)
# Coef:  -0.724380619974 Intercept:  648.99541758 intersection_x:  477.87910004
# Point one:  (472, 306) Point two:  (0, 648)
#   8%|▊         | 52/682 [00:02<00:26, 23.61it/s]
# Coef:
#   8%|▊         | 55/682 [00:02<00:33, 18.50it/s]
#  0.587968236546 Intercept:  26.4034713519 intersection_x:  474.965646842
# Point one:  (479, 308) Point two:  (960, 590)
# Coef:  -0.716983179084 Intercept:  646.210564573 intersection_x:  474.965646842
# Point one:  (469, 309) Point two:  (0, 646)
# Coef:  0.602754669218 Intercept:  17.4303718296 intersection_x:  475.306456487
# Point one:  (480, 306) Point two:  (960, 596)
# Coef:  -0.73225609673 Intercept:  651.969608364 intersection_x:  475.306456487
# Point one:  (470, 307) Point two:  (0, 651)
# Coef:  0.603055991627 Intercept:  18.1419989534 intersection_x:  474.641771142
# Point one:  (479, 307) Point two:  (960, 597)
# Coef:  -0.739951989543 Intercept:  655.589685794 intersection_x:  474.641771142
# Point one:  (469, 308) Point two:  (0, 655)
# Coef:  0.557692307692 Intercept:  45.6346153846 intersection_x:  473.041801686
# Point one:  (478, 312) Point two:  (960, 581)
# Coef:  -0.718367620588 Intercept:  649.264302918 intersection_x:  473.041801686
# Point one:  (468, 313) Point two:  (0, 649)
# Coef:  0.573913043478 Intercept:  31.9304347826 intersection_x:  475.322360238
# Point one:  (480, 307) Point two:  (960, 582)
# Coef:  -0.724983081084 Intercept:  649.324806413 intersection_x:  475.322360238
# Point one:  (470, 308) Point two:  (0, 649)
# Coef:  0.610339506173 Intercept:  12.7330246914 intersection_x:  476.554935958
# Point one:  (481, 306) Point two:  (960, 598)
# Coef:  -0.734066005627 Intercept:  653.416107269 intersection_x:  476.554935958
# Point one:  (471, 307) Point two:  (0, 653)
#   9%|▉         | 62/682 [00:03<00:28, 21.56it/s]
# Coef:  0.624835309618 Intercept:  2.76350461133 intersection_x:  477.425499491
# Point one:  (482, 304) Point two:  (960, 602)
# Coef:  -0.755779554093 Intercept:  661.904245523 intersection_x:  477.425499491
# Point one:  (472, 304) Point two:  (0, 661)
# Coef:  0.608665269043 Intercept:  15.2448637317 intersection_x:  474.20793666
# Point one:  (479, 306) Point two:  (960, 599)
# Coef:  -0.753853336223 Intercept:  661.362000196 intersection_x:  474.20793666
# Point one:  (469, 307) Point two:  (0, 661)
# Coef:  0.611320754717 Intercept:  13.1320754717 intersection_x:  477.875694974
# Point one:  (482, 308) Point two:  (960, 600)
# Coef:  -0.718982297267 Intercept:  648.851570964 intersection_x:  477.875694974
# Point one:  (472, 308) Point two:  (0, 648)
# Coef:  0.609531084734 Intercept:  13.3239511106 intersection_x:  477.974954609
# Point one:  (482, 307) Point two:  (960, 598)
# Coef:  -0.70432889354 Intercept:  641.316114589 intersection_x:  477.974954609
# Point one:  (472, 308) Point two:  (0, 641)
# Coef:  0.602282718625 Intercept:  17.9668616657 intersection_x:  473.335567869
# Point one:  (478, 306) Point two:  (960, 596)
# Coef:  -0.711888046271 Intercept:  640.010626945 intersection_x:  473.335567869
# Point one:  (468, 306) Point two:  (0, 640)
#  10%|▉         | 68/682 [00:03<00:25, 23.87it/s]
# Coef:  0.616312703431 Intercept:  7.41145950757 intersection_x:  480.772184271
# Point one:  (485, 306) Point two:  (960, 599)
# Coef:  -0.687081212409 Intercept:  634.046999391 intersection_x:  480.772184271
# Point one:  (475, 307) Point two:  (0, 634)
# Coef:  0.617365724249 Intercept:  8.42576083352 intersection_x:  478.929834228
# Point one:  (483, 307) Point two:  (960, 601)
# Coef:  -0.696096053236 Intercept:  637.481792189 intersection_x:  478.929834228
# Point one:  (473, 307) Point two:  (0, 637)
# Coef:  0.590283961269 Intercept:  24.3116203624 intersection_x:  474.49455156
# Point one:  (479, 307) Point two:  (960, 590)
# Coef:  -0.711923039326 Intercept:  642.201747149 intersection_x:  474.49455156
# Point one:  (469, 307) Point two:  (0, 642)
# Coef:  0.589593040302 Intercept:  27.9247044327 intersection_x:  473.505412797
# Point one:  (478, 310) Point two:  (960, 593)
# Coef:  -0.70960988533 Intercept:  643.104322041 intersection_x:  473.505412797
# Point one:  (468, 310) Point two:  (0, 643)
# Coef:  0.619130357302 Intercept:  8.46716564199 intersection_x:  479.032431636
# Point one:  (484, 308) Point two:  (960, 602)
# Coef:  -0.700033671516 Intercept:  640.389518093 intersection_x:  479.032431636
# Point one:  (474, 308) Point two:  (0, 640)
# Coef:  0.583533447684 Intercept:  31.1067753002 intersection_x:  472.71171147
# Point one:  (477, 309) Point two:  (960, 591)
# Coef:  -0.710738691415 Intercept:  642.924373282 intersection_x:  472.71171147
# Point one:  (467, 310) Point two:  (0, 642)
#  11%|█         | 74/682 [00:03<00:24, 24.53it/s]
# Coef:  0.583878589604 Intercept:  30.8173391494 intersection_x:  473.725235957
# Point one:  (478, 310) Point two:  (960, 591)
# Coef:  -0.705853112657 Intercept:  641.795794124 intersection_x:  473.725235957
# Point one:  (468, 310) Point two:  (0, 641)
# Coef:  0.618192819685 Intercept:  10.3227107705 intersection_x:  477.925372516
# Point one:  (482, 308) Point two:  (960, 603)
# Coef:  -0.706608407511 Intercept:  643.478830788 intersection_x:  477.925372516
# Point one:  (472, 309) Point two:  (0, 643)
# Coef:  0.61188266857 Intercept:  13.3840981905 intersection_x:  478.764323544
# Point one:  (483, 309) Point two:  (960, 600)
# Coef:  -0.715329282118 Intercept:  648.805829961 intersection_x:  478.764323544
# Point one:  (473, 309) Point two:  (0, 648)
# Coef:  0.607988417646 Intercept:  17.4901209334 intersection_x:  477.971858102
# Point one:  (482, 311) Point two:  (960, 601)
# Coef:  -0.699615988063 Intercept:  642.488228392 intersection_x:  477.971858102
# Point one:  (472, 311) Point two:  (0, 642)
# Coef:  0.629551443287 Intercept:  3.64663432746 intersection_x:  481.720103161
# Point one:  (486, 310) Point two:  (960, 608)
# Coef:  -0.698274057442 Intercept:  643.286871518 intersection_x:  481.720103161
# Point one:  (476, 310) Point two:  (0, 643)
# Coef:  0.601213303001 Intercept:  22.408319792 intersection_x:  477.223118881
# Point one:  (482, 312) Point two:  (960, 599)
# Coef:  -0.702061563803 Intercept:  644.361216487 intersection_x:  477.223118881
# Point one:  (472, 312) Point two:  (0, 644)
#  12%|█▏        | 80/682 [00:03<00:24, 24.35it/s]
# Coef:  0.62306292009 Intercept:  9.03549757282 intersection_x:  478.864005749
# Point one:  (483, 310) Point two:  (960, 607)
# Coef:  -0.707563438458 Intercept:  646.224565782 intersection_x:  478.864005749
# Point one:  (473, 310) Point two:  (0, 646)
# Coef:  0.635334830939 Intercept:  2.72515150937 intersection_x:  479.040479841
# Point one:  (484, 310) Point two:  (960, 612)
# Coef:  -0.708256415771 Intercept:  646.359747044 intersection_x:  479.040479841
# Point one:  (474, 310) Point two:  (0, 646)
# Coef:  0.60465952742 Intercept:  21.8856326992 intersection_x:  476.674114092
# Point one:  (481, 313) Point two:  (960, 602)
# Coef:  -0.699889834305 Intercept:  643.730543989 intersection_x:  476.674114092
# Point one:  (471, 313) Point two:  (0, 643)
# Coef:  0.618307220084 Intercept:  14.3843691589 intersection_x:  478.386167379
# Point one:  (483, 313) Point two:  (960, 607)
# Coef:  -0.697159713814 Intercept:  643.68555398 intersection_x:  478.386167379
# Point one:  (473, 313) Point two:  (0, 643)
# Coef:  0.623303823053 Intercept:  8.94645551628 intersection_x:  475.266493042
# Point one:  (480, 308) Point two:  (960, 607)
# Coef:  -0.712561042956 Intercept:  643.838265562 intersection_x:  475.266493042
# Point one:  (470, 308) Point two:  (0, 643)
#  12%|█▏        | 83/682 [00:04<00:23, 25.30it/s]
# Coef:  0.621081126104 Intercept:  8.28671497585 intersection_x:  477.47697676
# Point one:  (482, 307) Point two:  (960, 604)
# Coef:  -0.708555429085 Intercept:  643.157557537 intersection_x:  477.47697676
# Point one:  (472, 308) Point two:  (0, 643)
# Coef:  0.611565420561 Intercept:  14.4398364486 intersection_x:  474.466169956
# Point one:  (479, 307) Point two:  (960, 601)
# Coef:  -0.711476443658 Intercept:  642.178442456 intersection_x:  474.466169956
# Point one:  (469, 308) Point two:  (0, 642)
# Coef:  0.604810564113 Intercept:  18.2249907715 intersection_x:  473.650526952
# Point one:  (478, 307) Point two:  (960, 598)
# Coef:  -0.71237176102 Intercept:  642.109093163 intersection_x:  473.650526952
# Point one:  (468, 308) Point two:  (0, 642)
# Coef:  0.670723385399 Intercept:  -20.1941641741 intersection_x:  480.697533601
# Point one:  (485, 305) Point two:  (960, 623)
# Coef:  -0.703327808425 Intercept:  640.308855739 intersection_x:  480.697533601
# Point one:  (475, 305) Point two:  (0, 640)
# Coef:  0.6438918329 Intercept:  -3.76804097614 intersection_x:  477.203348099
# Point one:  (482, 306) Point two:  (960, 614)
# Coef:  -0.722406564014 Intercept:  648.234128533 intersection_x:  477.203348099
# Point one:  (472, 307) Point two:  (0, 648)
# Coef:  0.633411214953 Intercept:  1.87126168224 intersection_x:  479.147421233
# Point one:  (484, 308) Point two:  (960, 609)
# Coef:  -0.701079600376 Intercept:  641.289094507 intersection_x:  479.147421233
# Point one:  (474, 308) Point two:  (0, 641)
# Coef:  0.644183045464 Intercept:  -5.38093110979 intersection_x:  481.780675931
# Point one:  (486, 308) Point two:  (960, 613)
# Coef:  -0.695467577886 Intercept:  640.036851719 intersection_x:  481.780675931
# Point one:  (476, 308) Point two:  (0, 640)
#  13%|█▎        | 90/682 [00:04<00:22, 26.84it/s]
# Coef:  0.613248439251 Intercept:  13.9579101581 intersection_x:  476.950889403
# Point one:  (481, 309) Point two:  (960, 602)
# Coef:  -0.682888936982 Intercept:  632.151784541 intersection_x:  476.950889403
# Point one:  (471, 309) Point two:  (0, 632)
# Coef:  0.629522742065 Intercept:  3.03900468126 intersection_x:  480.194666073
# Point one:  (485, 308) Point two:  (960, 607)
# Coef:  -0.690188346883 Intercept:  636.757230352 intersection_x:  480.194666073
# Point one:  (475, 308) Point two:  (0, 636)
# Coef:  0.616577024405 Intercept:  14.7300413983 intersection_x:  478.035918974
# Point one:  (483, 312) Point two:  (960, 606)
# Coef:  -0.684125771858 Intercept:  636.512697921 intersection_x:  478.035918974
# Point one:  (473, 312) Point two:  (0, 636)
# Coef:  0.644203192265 Intercept:  -3.43283984687 intersection_x:  479.012262455
# Point one:  (484, 308) Point two:  (960, 615)
# Coef:  -0.6910969862 Intercept:  636.192319696 intersection_x:  479.012262455
# Point one:  (474, 308) Point two:  (0, 636)
# Coef:  0.615309196294 Intercept:  14.6235598955 intersection_x:  477.594370822
# Point one:  (482, 311) Point two:  (960, 605)
# Coef:  -0.693200155781 Intercept:  639.560260615 intersection_x:  477.594370822
# Point one:  (472, 311) Point two:  (0, 639)
# Coef:  0.628204314371 Intercept:  8.98362340877 intersection_x:  478.273172231
# Point one:  (483, 312) Point two:  (960, 612)
# Coef:  -0.687431791477 Intercept:  638.217077255 intersection_x:  478.273172231
# Point one:  (473, 312) Point two:  (0, 638)
#  14%|█▍        | 96/682 [00:04<00:21, 27.33it/s]
# Coef:  0.577777777778 Intercept:  38.9 intersection_x:  474.360397541
# Point one:  (479, 315) Point two:  (960, 593)
# Coef:  -0.693068029186 Intercept:  641.738922204 intersection_x:  474.360397541
# Point one:  (469, 316) Point two:  (0, 641)
# Coef:  0.617950392413 Intercept:  14.1280107546 intersection_x:  477.896074385
# Point one:  (482, 312) Point two:  (960, 607)
# Coef:  -0.69235726404 Intercept:  640.31889601 intersection_x:  477.896074385
# Point one:  (472, 312) Point two:  (0, 640)
# Coef:  0.604521276596 Intercept:  22.7654255319 intersection_x:  477.050396109
# Point one:  (482, 314) Point two:  (960, 603)
# Coef:  -0.688737048347 Intercept:  639.714821717 intersection_x:  477.050396109
# Point one:  (472, 314) Point two:  (0, 639)
# Coef:  0.623333333333 Intercept:  11.5366666667 intersection_x:  478.734092305
# Point one:  (483, 313) Point two:  (960, 609)
# Coef:  -0.688541899473 Intercept:  639.576065462 intersection_x:  478.734092305
# Point one:  (473, 313) Point two:  (0, 639)
# Coef:  0.614889648077 Intercept:  15.8175250272 intersection_x:  478.649775471
# Point one:  (483, 313) Point two:  (960, 606)
# Coef:  -0.692353123367 Intercept:  641.528984065 intersection_x:  478.649775471
# Point one:  (473, 313) Point two:  (0, 641)
# Coef:  0.629360578076 Intercept:  7.19207915607 intersection_x:  479.923220498
# Point one:  (484, 312) Point two:  (960, 611)
# Coef:  -0.689940404153 Intercept:  640.355255354 intersection_x:  479.923220498
# Point one:  (474, 312) Point two:  (0, 640)
#  15%|█▍        | 102/682 [00:04<00:21, 27.05it/s]
# Coef:  0.632631101941 Intercept:  3.82687378882 intersection_x:  481.373066331
# Point one:  (486, 311) Point two:  (960, 611)
# Coef:  -0.691355625796 Intercept:  641.158424701 intersection_x:  481.373066331
# Point one:  (476, 311) Point two:  (0, 641)
# Coef:  0.650238491486 Intercept:  -7.3583947517 intersection_x:  480.449065175
# Point one:  (485, 308) Point two:  (960, 616)
# Coef:  -0.715712179578 Intercept:  648.911328236 intersection_x:  480.449065175
# Point one:  (475, 308) Point two:  (0, 648)
# Coef:  0.596016641254 Intercept:  27.0546970743 intersection_x:  474.714966835
# Point one:  (479, 312) Point two:  (960, 599)
# Coef:  -0.703439002222 Intercept:  643.925739771 intersection_x:  474.714966835
# Point one:  (469, 313) Point two:  (0, 643)
# Coef:  0.63612480443 Intercept:  3.78273195455 intersection_x:  478.134484387
# Point one:  (483, 311) Point two:  (960, 614)
# Coef:  -0.69255278102 Intercept:  639.069304191 intersection_x:  478.134484387
# Point one:  (473, 311) Point two:  (0, 639)
# Coef:  0.624108658744 Intercept:  9.94355781928 intersection_x:  476.626831586
# Point one:  (481, 310) Point two:  (960, 609)
# Coef:  -0.693496331134 Intercept:  637.949449426 intersection_x:  476.626831586
# Point one:  (471, 310) Point two:  (0, 637)
# Coef:  0.630953780519 Intercept:  4.20995352474 intersection_x:  479.551929548
# Point one:  (484, 309) Point two:  (960, 609)
# Coef:  -0.688707518494 Intercept:  637.056075817 intersection_x:  479.551929548
# Point one:  (474, 310) Point two:  (0, 637)
# Coef:  0.65295600993 Intercept:  -9.03991184369 intersection_x:  481.53098125
# Point one:  (486, 308) Point two:  (960, 617)
# Coef:  -0.699435418544 Intercept:  642.178459744 intersection_x:  481.53098125
# Point one:  (476, 308) Point two:  (0, 642)
#  16%|█▌        | 110/682 [00:04<00:19, 28.89it/s]
# Coef:  0.646234872255 Intercept:  -4.38827879874 intersection_x:  481.681846967
# Point one:  (486, 310) Point two:  (960, 615)
# Coef:  -0.675007907558 Intercept:  632.030383673 intersection_x:  481.681846967
# Point one:  (476, 310) Point two:  (0, 632)
# Coef:  0.600135903138 Intercept:  23.794600939 intersection_x:  476.647206818
# Point one:  (481, 312) Point two:  (960, 599)
# Coef:  -0.683498891934 Intercept:  635.635540585 intersection_x:  476.647206818
# Point one:  (471, 313) Point two:  (0, 635)
# Coef:  0.612378296841 Intercept:  16.996983133 intersection_x:  476.82391494
# Point one:  (481, 312) Point two:  (960, 604)
# Coef:  -0.688591441545 Intercept:  637.330467008 intersection_x:  476.82391494
# Point one:  (471, 312) Point two:  (0, 637)
# Coef:  0.617088666267 Intercept:  15.4075257454 intersection_x:  478.449502481
# Point one:  (483, 313) Point two:  (960, 607)
# Coef:  -0.688423185733 Intercept:  640.029021818 intersection_x:  478.449502481
# Point one:  (473, 314) Point two:  (0, 640)
# Coef:  0.614944271742 Intercept:  16.1886420502 intersection_x:  478.955510987
# Point one:  (483, 313) Point two:  (960, 606)
# Coef:  -0.671182311011 Intercept:  632.186056687 intersection_x:  478.955510987
# Point one:  (473, 314) Point two:  (0, 632)
# Coef:  0.616361537193 Intercept:  15.326488537 intersection_x:  476.932332376
# Point one:  (481, 312) Point two:  (960, 607)
# Coef:  -0.704597321 Intercept:  645.334477747 intersection_x:  476.932332376
# Point one:  (471, 312) Point two:  (0, 645)
#  17%|█▋        | 116/682 [00:05<00:20, 27.76it/s]
# Coef:  0.635486135486 Intercept:  2.38592488592 intersection_x:  481.314056002
# Point one:  (486, 311) Point two:  (960, 612)
# Coef:  -0.701086658347 Intercept:  645.697197427 intersection_x:  481.314056002
# Point one:  (476, 311) Point two:  (0, 645)
# Coef:  0.646807219141 Intercept:  -4.46094315897 intersection_x:  482.671068382
# Point one:  (487, 310) Point two:  (960, 616)
# Coef:  -0.69916445328 Intercept:  645.200641981 intersection_x:  482.671068382
# Point one:  (477, 311) Point two:  (0, 645)
# Coef:  0.640005996033 Intercept:  -0.528899958489 intersection_x:  482.370633182
# Point one:  (487, 311) Point two:  (960, 613)
# Coef:  -0.687097485135 Intercept:  639.62684655 intersection_x:  482.370633182
# Point one:  (477, 311) Point two:  (0, 639)
# Coef:  0.616438215118 Intercept:  14.046655598 intersection_x:  476.489686707
# Point one:  (481, 310) Point two:  (960, 605)
# Coef:  -0.714725484208 Intercept:  648.332429645 intersection_x:  476.489686707
# Point one:  (471, 311) Point two:  (0, 648)
# Coef:  0.632915751023 Intercept:  1.85367469696 intersection_x:  481.099596301
# Point one:  (486, 309) Point two:  (960, 609)
# Coef:  -0.685701186347 Intercept:  636.239750941 intersection_x:  481.099596301
# Point one:  (476, 309) Point two:  (0, 636)
# Coef:  0.633714648882 Intercept:  1.65740641626 intersection_x:  481.993315084
# Point one:  (486, 310) Point two:  (960, 610)
# Coef:  -0.696006644786 Intercept:  642.574180889 intersection_x:  481.993315084
# Point one:  (476, 310) Point two:  (0, 642)
#  18%|█▊        | 120/682 [00:05<00:19, 28.22it/s]
# Coef:  0.640170940171 Intercept:  -2.1094017094 intersection_x:  483.690880066
# Point one:  (488, 310) Point two:  (960, 612)
# Coef:  -0.677604825904 Intercept:  635.286718313 intersection_x:  483.690880066
# Point one:  (478, 310) Point two:  (0, 635)
# Coef:  0.633614466986 Intercept:  2.37231213434 intersection_x:  478.513897313
# Point one:  (483, 308) Point two:  (960, 610)
# Coef:  -0.721758430253 Intercept:  650.937079504 intersection_x:  478.513897313
# Point one:  (473, 309) Point two:  (0, 650)
# Coef:  0.660344827586 Intercept:  -14.5034482759 intersection_x:  480.693844499
# Point one:  (485, 306) Point two:  (960, 619)
# Coef:  -0.719950830678 Intercept:  648.996178241 intersection_x:  480.693844499
# Point one:  (475, 306) Point two:  (0, 648)
# Coef:  0.625182724252 Intercept:  7.06372093023 intersection_x:  482.804066127
# Point one:  (487, 312) Point two:  (960, 607)
# Coef:  -0.68136526237 Intercept:  637.870401462 intersection_x:  482.804066127
# Point one:  (477, 312) Point two:  (0, 637)
# Coef:  0.613643410853 Intercept:  13.2435658915 intersection_x:  477.957609005
# Point one:  (482, 309) Point two:  (960, 602)
# Coef:  -0.720758522277 Intercept:  651.031123302 intersection_x:  477.957609005
# Point one:  (472, 310) Point two:  (0, 651)
# Coef:  0.637278013516 Intercept:  -0.105139085337 intersection_x:  484.657389578
# Point one:  (489, 311) Point two:  (960, 611)
# Coef:  -0.690266869849 Intercept:  643.299298633 intersection_x:  484.657389578
# Point one:  (479, 312) Point two:  (0, 643)
#  19%|█▊        | 127/682 [00:05<00:20, 27.27it/s]
# Coef:  0.616006899678 Intercept:  11.8294625824 intersection_x:  479.515648177
# Point one:  (484, 310) Point two:  (960, 603)
# Coef:  -0.714791491327 Intercept:  649.968115638 intersection_x:  479.515648177
# Point one:  (474, 310) Point two:  (0, 649)
# Coef:  0.642448057241 Intercept:  -3.08031012934 intersection_x:  481.389366448
# Point one:  (486, 309) Point two:  (960, 613)
# Coef:  -0.709642167295 Intercept:  647.801546441 intersection_x:  481.389366448
# Point one:  (476, 309) Point two:  (0, 647)
# Coef:  0.625667493129 Intercept:  7.69133919872 intersection_x:  477.979314163
# Point one:  (482, 309) Point two:  (960, 608)
# Coef:  -0.717001678877 Intercept:  649.459429182 intersection_x:  477.979314163
# Point one:  (472, 310) Point two:  (0, 649)
# Coef:  0.638644873631 Intercept:  -1.05711384807 intersection_x:  483.154442981
# Point one:  (488, 310) Point two:  (960, 612)
# Coef:  -0.695642512089 Intercept:  643.609764776 intersection_x:  483.154442981
# Point one:  (478, 310) Point two:  (0, 643)
# Coef:  0.619591565524 Intercept:  11.7710020088 intersection_x:  482.049634246
# Point one:  (487, 313) Point two:  (960, 606)
# Coef:  -0.684652674547 Intercept:  640.481460903 intersection_x:  482.049634246
# Point one:  (477, 313) Point two:  (0, 640)
# Coef:  0.622330539045 Intercept:  12.4008149408 intersection_x:  475.61868921
# Point one:  (480, 311) Point two:  (960, 609)
# Coef:  -0.711039464071 Intercept:  646.576508054 intersection_x:  475.61868921
# Point one:  (470, 311) Point two:  (0, 646)
#  20%|█▉        | 133/682 [00:05<00:20, 27.19it/s]
# Coef:  0.631857031857 Intercept:  2.57384615385 intersection_x:  483.448644507
# Point one:  (488, 311) Point two:  (960, 609)
# Coef:  -0.694284330465 Intercept:  643.695090193 intersection_x:  483.448644507
# Point one:  (478, 311) Point two:  (0, 643)
# Coef:  0.633839754024 Intercept:  2.3393018629 intersection_x:  483.244796669
# Point one:  (488, 311) Point two:  (960, 610)
# Coef:  -0.691019507581 Intercept:  642.570646353 intersection_x:  483.244796669
# Point one:  (478, 312) Point two:  (0, 642)
# Coef:  0.636030374444 Intercept:  0.25661167845 intersection_x:  478.882449626
# Point one:  (483, 308) Point two:  (960, 610)
# Coef:  -0.726855732564 Intercept:  652.918849163 intersection_x:  478.882449626
# Point one:  (473, 308) Point two:  (0, 652)
# Coef:  0.637212643678 Intercept:  -0.215517241379 intersection_x:  482.951510761
# Point one:  (487, 310) Point two:  (960, 611)
# Coef:  -0.695566228882 Intercept:  643.452052772 intersection_x:  482.951510761
# Point one:  (477, 311) Point two:  (0, 643)
# Coef:  0.633244977911 Intercept:  3.20468783863 intersection_x:  482.072481825
# Point one:  (487, 311) Point two:  (960, 611)
# Coef:  -0.699876872429 Intercept:  645.866046808 intersection_x:  482.072481825
# Point one:  (477, 311) Point two:  (0, 645)
# Coef:  0.63438697318 Intercept:  1.79511494253 intersection_x:  482.748879357
# Point one:  (487, 311) Point two:  (960, 610)
# Coef:  -0.705488398933 Intercept:  648.618449308 intersection_x:  482.748879357
# Point one:  (477, 311) Point two:  (0, 648)
#  21%|██        | 142/682 [00:06<00:19, 28.04it/s]
# Coef:  0.600008681908 Intercept:  24.5384186594 intersection_x:  478.361137137
# Point one:  (483, 314) Point two:  (960, 600)
# Coef:  -0.699525890476 Intercept:  646.185254454 intersection_x:  478.361137137
# Point one:  (473, 315) Point two:  (0, 646)
# Coef:  0.621976294146 Intercept:  9.84409772617 intersection_x:  480.893821676
# Point one:  (485, 312) Point two:  (960, 606)
# Coef:  -0.700922233569 Intercept:  646.017826409 intersection_x:  480.893821676
# Point one:  (475, 312) Point two:  (0, 646)
# Coef:  0.62421612542 Intercept:  8.40517917133 intersection_x:  480.351816858
# Point one:  (485, 311) Point two:  (960, 607)
# Coef:  -0.709098498264 Intercept:  648.865281101 intersection_x:  480.351816858
# Point one:  (475, 311) Point two:  (0, 648)
# Coef:  0.618851897065 Intercept:  12.5481309381 intersection_x:  473.872263639
# Point one:  (478, 308) Point two:  (960, 606)
# Coef:  -0.728598090624 Intercept:  651.067306745 intersection_x:  473.872263639
# Point one:  (468, 309) Point two:  (0, 651)
# Coef:  0.606694246915 Intercept:  23.0753376552 intersection_x:  476.277745198
# Point one:  (481, 315) Point two:  (960, 605)
# Coef:  -0.684104323113 Intercept:  637.853970093 intersection_x:  476.277745198
# Point one:  (471, 315) Point two:  (0, 637)
# Coef:  0.641058519718 Intercept:  -2.94438987284 intersection_x:  483.263573011
# Point one:  (488, 310) Point two:  (960, 612)
# Coef:  -0.699791964183 Intercept:  645.039805851 intersection_x:  483.263573011
# Point one:  (478, 310) Point two:  (0, 645)
#  21%|██▏       | 145/682 [00:06<00:19, 27.24it/s]
# Coef:  0.633819154662 Intercept:  2.30125658978 intersection_x:  482.171797291
# Point one:  (487, 311) Point two:  (960, 610)
# Coef:  -0.68983771178 Intercept:  640.531266879 intersection_x:  482.171797291
# Point one:  (477, 311) Point two:  (0, 640)
# Coef:  0.638030194105 Intercept:  0.404385334292 intersection_x:  480.229148406
# Point one:  (485, 309) Point two:  (960, 612)
# Coef:  -0.714514459997 Intercept:  649.935752755 intersection_x:  480.229148406
# Point one:  (475, 310) Point two:  (0, 649)
# Coef:  0.601839965768 Intercept:  21.7567394095 intersection_x:  481.297179938
# Point one:  (486, 314) Point two:  (960, 599)
# Coef:  -0.687774660953 Intercept:  642.444622457 intersection_x:  481.297179938
# Point one:  (476, 314) Point two:  (0, 642)
# Coef:  0.612048757618 Intercept:  16.2053445851 intersection_x:  479.754661342
# Point one:  (484, 312) Point two:  (960, 603)
# Coef:  -0.689214696094 Intercept:  640.492552137 intersection_x:  479.754661342
# Point one:  (474, 313) Point two:  (0, 640)
# Coef:  0.630090752269 Intercept:  4.68667966699 intersection_x:  482.92617114
# Point one:  (487, 312) Point two:  (960, 609)
# Coef:  -0.671190497303 Intercept:  633.109451099 intersection_x:  482.92617114
# Point one:  (477, 312) Point two:  (0, 633)
# Coef:  0.636988751887 Intercept:  1.04254038064 intersection_x:  480.852320165
# Point one:  (485, 310) Point two:  (960, 612)
# Coef:  -0.704670267805 Intercept:  646.182392871 intersection_x:  480.852320165
# Point one:  (475, 310) Point two:  (0, 646)
#  22%|██▏       | 151/682 [00:06<00:19, 27.33it/s]
# Coef:  0.620728977116 Intercept:  11.0870074442 intersection_x:  480.352770443
# Point one:  (485, 312) Point two:  (960, 606)
# Coef:  -0.70669490738 Intercept:  648.718747914 intersection_x:  480.352770443
# Point one:  (475, 312) Point two:  (0, 648)
# Coef:  0.622262989703 Intercept:  8.34702331637 intersection_x:  481.322457314
# Point one:  (486, 310) Point two:  (960, 605)
# Coef:  -0.71473863591 Intercept:  651.875931189 intersection_x:  481.322457314
# Point one:  (476, 311) Point two:  (0, 651)
# Coef:  0.591803656726 Intercept:  28.3258851499 intersection_x:  477.654543586
# Point one:  (482, 313) Point two:  (960, 596)
# Coef:  -0.720951514017 Intercept:  655.369357071 intersection_x:  477.654543586
# Point one:  (472, 314) Point two:  (0, 655)
# Coef:  0.60670859284 Intercept:  19.7170399685 intersection_x:  478.685530602
# Point one:  (483, 313) Point two:  (960, 602)
# Coef:  -0.704908389 Intercept:  647.569110867 intersection_x:  478.685530602
# Point one:  (473, 313) Point two:  (0, 647)
# Coef:  0.622137699163 Intercept:  8.17138437339 intersection_x:  483.277140681
# Point one:  (488, 311) Point two:  (960, 605)
# Coef:  -0.703216074065 Intercept:  648.68456629 intersection_x:  483.277140681
# Point one:  (478, 312) Point two:  (0, 648)
# Coef:  0.601858932462 Intercept:  22.4158039216 intersection_x:  484.122189049
# Point one:  (489, 316) Point two:  (960, 600)
# Coef:  -0.685085277791 Intercept:  645.454052173 intersection_x:  484.122189049
# Point one:
#  23%|██▎       | 158/682 [00:06<00:18, 27.88it/s]
#  (479, 317) Point two:  (0, 645)
# Coef:  0.611254093548 Intercept:  16.0760096108 intersection_x:  481.912453265
# Point one:  (486, 313) Point two:  (960, 602)
# Coef:  -0.715902070442 Intercept:  655.649092465 intersection_x:  481.912453265
# Point one:  (476, 314) Point two:  (0, 655)
# Coef:  0.590280437756 Intercept:  30.9809439124 intersection_x:  478.854963786
# Point one:  (483, 316) Point two:  (960, 597)
# Coef:  -0.703546613464 Intercept:  650.53644967 intersection_x:  478.854963786
# Point one:  (473, 317) Point two:  (0, 650)
# Coef:  0.601276742581 Intercept:  22.2505175983 intersection_x:  480.73203199
# Point one:  (485, 314) Point two:  (960, 599)
# Coef:  -0.709389982951 Intercept:  652.329995825 intersection_x:  480.73203199
# Point one:  (475, 314) Point two:  (0, 652)
# Coef:  0.588366981439 Intercept:  29.8215157929 intersection_x:  481.225002248
# Point one:  (486, 315) Point two:  (960, 594)
# Coef:  -0.711567082361 Intercept:  655.382288568 intersection_x:  481.225002248
# Point one:  (476, 316) Point two:  (0, 655)
# Coef:  0.571719955588 Intercept:  38.6691324417 intersection_x:  483.983873089
# Point one:  (488, 318) Point two:  (960, 587)
# Coef:  -0.679906076572 Intercept:  644.435947145 intersection_x:  483.983873089
# Point one:  (478, 318) Point two:  (0, 644)
# Coef:  0.578294328484 Intercept:  36.203826692 intersection_x:  480.606868626
# Point one:  (485, 317) Point two:  (960, 591)
# Coef:  -0.715616515714 Intercept:  658.066265803 intersection_x:  480.606868626
# Point one:  (475, 317) Point two:  (0, 658)
#  24%|██▍       | 164/682 [00:06<00:19, 26.64it/s]
# Coef:  0.578495887192 Intercept:  35.9421073247 intersection_x:  480.851530107
# Point one:  (485, 317) Point two:  (960, 591)
# Coef:  -0.732835510669 Intercept:  666.497816464 intersection_x:  480.851530107
# Point one:  (475, 317) Point two:  (0, 666)
# Coef:  0.591707296592 Intercept:  28.5057550175 intersection_x:  480.830294419
# Point one:  (485, 315) Point two:  (960, 596)
# Coef:  -0.713735783156 Intercept:  656.202335399 intersection_x:  480.830294419
# Point one:  (475, 316) Point two:  (0, 656)
# Coef:  0.560388710462 Intercept:  49.145940624 intersection_x:  475.532993402
# Point one:  (480, 318) Point two:  (960, 587)
# Coef:  -0.723891552533 Intercept:  659.863578452 intersection_x:  475.532993402
# Point one:  (470, 319) Point two:  (0, 659)
# Coef:  0.592638000109 Intercept:  25.3909279453 intersection_x:  482.139922294
# Point one:  (487, 314) Point two:  (960, 594)
# Coef:  -0.714545326273 Intercept:  655.636195351 intersection_x:  482.139922294
# Point one:  (477, 314) Point two:  (0, 655)
# Coef:  0.607165003025 Intercept:  15.3503024803 intersection_x:  485.40990674
# Point one:  (490, 313) Point two:  (960, 598)
# Coef:  -0.721283657644 Intercept:  660.192442965 intersection_x:  485.40990674
# Point one:  (480, 313) Point two:  (0, 660)
# Coef:  0.587006383149 Intercept:  29.8348571411 intersection_x:  481.383416837
# Point one:  (486, 315) Point two:  (960, 593)
# Coef:  -0.709873965372 Intercept:  654.131550541 intersection_x:  481.383416837
# Point one:  (476, 315) Point two:  (0, 654)
#  25%|██▍       | 170/682 [00:07<00:18, 27.52it/s]
# Coef:  0.536691764806 Intercept:  64.5926026521 intersection_x:  472.072075153
# Point one:  (477, 320) Point two:  (960, 579)
# Coef:  -0.731244610075 Intercept:  663.149958304 intersection_x:  472.072075153
# Point one:  (467, 321) Point two:  (0, 663)
# Coef:  0.567512933407 Intercept:  41.8868649789 intersection_x:  479.706109467
# Point one:  (484, 316) Point two:  (960, 586)
# Coef:  -0.712651355294 Intercept:  655.98949539 intersection_x:  479.706109467
# Point one:  (474, 317) Point two:  (0, 655)
# Coef:  0.587343289086 Intercept:  26.7664085546 intersection_x:  484.047378178
# Point one:  (489, 314) Point two:  (960, 590)
# Coef:  -0.718747806801 Intercept:  658.97637918 intersection_x:  484.047378178
# Point one:  (479, 314) Point two:  (0, 658)
# Coef:  0.574078544986 Intercept:  34.6235313053 intersection_x:  483.989862384
# Point one:  (488, 315) Point two:  (960, 585)
# Coef:  -0.720296772744 Intercept:  661.088063206 intersection_x:  483.989862384
# Point one:  (478, 316) Point two:  (0, 661)
# Coef:  0.575827205882 Intercept:  33.0390625 intersection_x:  482.550738402
# Point one:  (487, 313) Point two:  (960, 585)
# Coef:  -0.753206086297 Intercept:  674.365059002 intersection_x:  482.550738402
# Point one:  (477, 314) Point two:  (0, 674)
# Coef:  0.573017049666 Intercept:  34.9955522609 intersection_x:  481.299250458
# Point one:  (486, 313) Point two:  (960, 585)
# Coef:  -0.743678369283 Intercept:  668.720070482 intersection_x:  481.299250458
# Point one:  (476, 314) Point two:  (0, 668)
#  26%|██▌       | 176/682 [00:07<00:18, 26.91it/s]
# Coef:  0.566037735849 Intercept:  41.6603773585 intersection_x:  479.191859489
# Point one:  (484, 315) Point two:  (960, 585)
# Coef:  -0.735626472584 Intercept:  665.407269828 intersection_x:  479.191859489
# Point one:  (474, 316) Point two:  (0, 665)
# Coef:  0.587512054002 Intercept:  23.9657666345 intersection_x:  482.943983288
# Point one:  (487, 310) Point two:  (960, 587)
# Coef:  -0.766958516631 Intercept:  678.099179263 intersection_x:  482.943983288
# Point one:  (477, 311) Point two:  (0, 678)
# Coef:  0.580415225691 Intercept:  28.8844803503 intersection_x:  482.447586942
# Point one:  (487, 311) Point two:  (960, 586)
# Coef:  -0.753627071891 Intercept:  672.489967697 intersection_x:  482.447586942
# Point one:  (477, 312) Point two:  (0, 672)
# Coef:  0.580862592927 Intercept:  28.3748411443 intersection_x:  483.652407274
# Point one:  (488, 312) Point two:  (960, 586)
# Coef:  -0.760488813168 Intercept:  677.122677702 intersection_x:  483.652407274
# Point one:  (478, 313) Point two:  (0, 677)
# Coef:  0.580422100957 Intercept:  27.8793583427 intersection_x:  485.328464159
# Point one:  (490, 312) Point two:  (960, 585)
# Coef:  -0.757127331353 Intercept:  677.030170063 intersection_x:  485.328464159
# Point one:  (480, 313) Point two:  (0, 677)
# Coef:  0.583355067604 Intercept:  26.8820502394 intersection_x:  483.847052104
# Point one:  (488, 312) Point two:  (960, 586)
# Coef:  -0.767065992527 Intercept:  680.279299283 intersection_x:  483.847052104
# Point one:  (478, 312) Point two:  (0, 680)
#  27%|██▋       | 184/682 [00:07<00:17, 28.60it/s]
# Coef:  0.589554747657 Intercept:  20.7022620165 intersection_x:  486.758426676
# Point one:  (491, 310) Point two:  (960, 586)
# Coef:  -0.751081397026 Intercept:  673.268202547 intersection_x:  486.758426676
# Point one:  (481, 311) Point two:  (0, 673)
# Coef:  0.537019111442 Intercept:  56.7423306031 intersection_x:  478.339547741
# Point one:  (483, 316) Point two:  (960, 572)
# Coef:  -0.765297452625 Intercept:  679.691846875 intersection_x:  478.339547741
# Point one:  (473, 317) Point two:  (0, 679)
# Coef:  0.558192459601 Intercept:  41.6267175704 intersection_x:  482.770933815
# Point one:  (487, 313) Point two:  (960, 577)
# Coef:  -0.747239424223 Intercept:  671.851287156 intersection_x:  482.770933815
# Point one:  (477, 314) Point two:  (0, 671)
# Coef:  0.574803149606 Intercept:  34.6377952756 intersection_x:  480.42024916
# Point one:  (485, 313) Point two:  (960, 586)
# Coef:  -0.760322533413 Intercept:  676.059208572 intersection_x:  480.42024916
# Point one:  (475, 314) Point two:  (0, 676)
# Coef:  0.545292451542 Intercept:  50.1637660388 intersection_x:  480.162559918
# Point one:  (485, 314) Point two:  (960, 573)
# Coef:  -0.756572427864 Intercept:  675.270539201 intersection_x:  480.162559918
# Point one:  (475, 315) Point two:  (0, 675)
# Coef:  0.548843368508 Intercept:  49.7546865301 intersection_x:  478.136366242
# ...
# Point one:  (471, 316) Point two:  (0, 655)
# Coef:  0.592005861694 Intercept:  31.154955911 intersection_x:  472.875577141
# Point one:  (477, 314) Point two:  (960, 599)
# Coef:  -0.729988705124 Intercept:  656.293899672 intersection_x:  472.875577141
# Point one:  (467, 314) Point two:  (0, 656)
# Coef:  0.566881402057 Intercept:  44.6978552826 intersection_x:  472.30345843
# Point one:  (477, 315) Point two:  (960, 588)
# Coef:  -0.745288045288 Intercept:  664.44002331 intersection_x:  472.30345843
# Point one:  (467, 316) Point two:  (0, 664)
# Coef:  0.582197780116 Intercept:  36.683346865 intersection_x:  476.800155716
# Point one:  (481, 317) Point two:  (960, 595)
# Coef:  -0.699322147735 Intercept:  647.712248018 intersection_x:  476.800155716
# Point one:  (471, 317) Point two:  (0, 647)
# Coef:  0.562064796654 Intercept:  47.4005583056 intersection_x:  470.451729159
# Point one:  (475, 314) Point two:  (960, 586)
# Coef:  -0.773076897263 Intercept:  675.520276881 intersection_x:  470.451729159
# Point one:  (465, 315) Point two:  (0, 675)
#  33%|███▎      | 222/682 [00:09<00:18, 24.93it/s]
# Coef:  0.586821562481 Intercept:  33.6298789108 intersection_x:  474.842119689
# Point one:  (479, 315) Point two:  (960, 596)
# Coef:  -0.727778155531 Intercept:  657.857195554 intersection_x:  474.842119689
# Point one:  (469, 315) Point two:  (0, 657)
# Coef:  0.584581569452 Intercept:  34.8049447438 intersection_x:  475.416256407
# Point one:  (480, 315) Point two:  (960, 596)
# Coef:  -0.732082611864 Intercept:  660.76850077 intersection_x:  475.416256407
# Point one:  (470, 316) Point two:  (0, 660)
# Coef:  0.616838988039 Intercept:  14.3805268627 intersection_x:  478.583776159
# Point one:  (483, 312) Point two:  (960, 606)
# Coef:  -0.741988722875 Intercept:  664.693423902 intersection_x:  478.583776159
# Point one:  (473, 313) Point two:  (0, 664)
# Coef:  0.60381201616 Intercept:  22.6097848208 intersection_x:  477.822170862
# Point one:  (482, 314) Point two:  (960, 602)
# Coef:  -0.726150253802 Intercept:  658.095243818 intersection_x:  477.822170862
# Point one:  (472, 314) Point two:  (0, 658)
# Coef:  0.606408247713 Intercept:  19.1268392138 intersection_x:  479.847103265
# Point one:  (484, 313) Point two:  (960, 601)
# Coef:  -0.729953188256 Intercept:  660.376003179 intersection_x:  479.847103265
# Point one:  (474, 313) Point two:  (0, 660)
# Coef:  0.606140811409 Intercept:  20.1368409454 intersection_x:  477.279618395
#  33%|███▎      | 228/682 [00:09<00:17, 25.85it/s]
# Point one:  (482, 312) Point two:  (960, 602)
# Coef:  -0.743077621881 Intercept:  664.091299917 intersection_x:  477.279618395
# Point one:  (472, 313) Point two:  (0, 664)
# Coef:  0.572755457222 Intercept:  41.8950084206 intersection_x:  474.170847136
# Point one:  (479, 316) Point two:  (960, 591)
# Coef:  -0.734649123366 Intercept:  661.828145948 intersection_x:  474.170847136
# Point one:  (469, 317) Point two:  (0, 661)
# Coef:  0.612152460984 Intercept:  13.9305522209 intersection_x:  481.166616424
# Point one:  (486, 311) Point two:  (960, 601)
# Coef:  -0.716345286631 Intercept:  653.159318368 intersection_x:  481.166616424
# Point one:  (476, 312) Point two:  (0, 653)
# Coef:  0.591118042311 Intercept:  29.1092305194 intersection_x:  471.379720888
# Point one:  (476, 310) Point two:  (960, 596)
# Coef:  -0.748074163138 Intercept:  660.377278539 intersection_x:  471.379720888
# Point one:  (466, 311) Point two:  (0, 660)
# Coef:  0.609108441708 Intercept:  15.1795683914 intersection_x:  480.579948141
# Point one:  (485, 310) Point two:  (960, 599)
# Coef:  -0.720188513118 Intercept:  654.013030005 intersection_x:  480.579948141
# Point one:  (475, 311) Point two:  (0, 654)
# Coef:  0.596316490352 Intercept:  24.8385030451 intersection_x:  478.073087944
# Point one:  (483, 312) Point two:  (960, 597)
# Coef:  -0.721100150987 Intercept:  654.659944879 intersection_x:  478.073087944
# Point one:  (473, 313) Point two:  (0, 654)
#  34%|███▍      | 234/682 [00:09<00:17, 25.47it/s]
# Coef:  0.632852400409 Intercept:  2.14715270684 intersection_x:  479.939460285
# Point one:  (484, 309) Point two:  (960, 609)
# Coef:  -0.735134000279 Intercept:  658.69780753 intersection_x:  479.939460285
# Point one:  (474, 309) Point two:  (0, 658)
# Coef:  0.621332425686 Intercept:  8.70843748582 intersection_x:  480.111681306
# Point one:  (485, 310) Point two:  (960, 605)
# Coef:  -0.72320048242 Intercept:  654.234392568 intersection_x:  480.111681306
# Point one:  (475, 310) Point two:  (0, 654)
# Coef:  0.587121212121 Intercept:  31.0984848485 intersection_x:  475.062412971
# Point one:  (480, 312) Point two:  (960, 594)
# Coef:  -0.711971352438 Intercept:  648.248533241 intersection_x:  475.062412971
# Point one:  (470, 313) Point two:  (0, 648)
# Coef:  0.61435357912 Intercept:  14.536383851 intersection_x:  478.672545023
# Point one:  (483, 311) Point two:  (960, 604)
# Coef:  -0.70401266115 Intercept:  645.602107354 intersection_x:  478.672545023
# Point one:  (473, 312) Point two:  (0, 645)
# Coef:  0.610816386678 Intercept:  17.1510462717 intersection_x:  478.106241611
# Point one:  (483, 312) Point two:  (960, 603)
# Coef:  -0.710873289428 Intercept:  649.059129891 intersection_x:  478.106241611
# Point one:  (473, 312) Point two:  (0, 649)
# Coef:  0.601556784756 Intercept:  21.7831564454 intersection_x:  476.174769689
# Point one:  (481, 311) Point two:  (960, 599)
# Coef:  -0.716422890088 Intercept:  649.371824569 intersection_x:  476.174769689
# Point one:  (471, 311) Point two:  (0, 649)
#  35%|███▌      | 240/682 [00:09<00:16, 26.93it/s]
# Coef:  0.614770476029 Intercept:  13.3347568914 intersection_x:  480.5471495
# Point one:  (485, 311) Point two:  (960, 603)
# Coef:  -0.688762628129 Intercept:  639.743874373 intersection_x:  480.5471495
# Point one:  (475, 312) Point two:  (0, 639)
# Coef:  0.622217165396 Intercept:  6.38223916259 intersection_x:  482.08459291
# Point one:  (487, 309) Point two:  (960, 603)
# Coef:  -0.706220041404 Intercept:  646.80134921 intersection_x:  482.08459291
# Point one:  (477, 309) Point two:  (0, 646)
# Coef:  0.62478074561 Intercept:  3.25551916921 intersection_x:  482.245533108
# Point one:  (487, 307) Point two:  (960, 603)
# Coef:  -0.711481093195 Intercept:  647.661821995 intersection_x:  482.245533108
# Point one:  (477, 308) Point two:  (0, 647)
# Coef:  0.592841850128 Intercept:  28.0305567339 intersection_x:  476.474265493
# Point one:  (481, 313) Point two:  (960, 597)
# Coef:  -0.700708567433 Intercept:  644.37404182 intersection_x:  476.474265493
# Point one:  (471, 314) Point two:  (0, 644)
# Coef:  0.629439464959 Intercept:  0.21933609505 intersection_x:  482.956948922
# Point one:  (487, 307) Point two:  (960, 604)
# Coef:  -0.713867005316 Intercept:  648.978530446 intersection_x:  482.956948922
# Point one:  (477, 307) Point two:  (0, 648)
# Coef:  0.570585137461 Intercept:  39.5984450287 intersection_x:  476.413003766
# Point one:  (481, 314) Point two:  (960, 587)
# Coef:  -0.700485513532 Intercept:  645.153031867 intersection_x:  476.413003766
# Point one:  (471, 314) Point two:  (0, 645)
#  36%|███▌      | 246/682 [00:09<00:15, 27.49it/s]
# Coef:  0.585312899106 Intercept:  30.9108556833 intersection_x:  475.585757032
# Point one:  (480, 312) Point two:  (960, 592)
# Coef:  -0.721592133077 Intercept:  652.456274783 intersection_x:  475.585757032
# Point one:  (470, 312) Point two:  (0, 652)
# Coef:  0.530380630893 Intercept:  63.8273192876 intersection_x:  471.276931151
# Point one:  (476, 316) Point two:  (960, 572)
# Coef:  -0.704201479199 Intercept:  645.657387386 intersection_x:  471.276931151
# Point one:  (466, 317) Point two:  (0, 645)
# Coef:  0.588356365775 Intercept:  30.2180241106 intersection_x:  479.470527164
# Point one:  (484, 315) Point two:  (960, 595)
# Coef:  -0.686889306992 Intercept:  641.660739096 intersection_x:  479.470527164
# Point one:  (474, 315) Point two:  (0, 641)
# Coef:  0.608465608466 Intercept:  19.0 intersection_x:  479.371931086
# Point one:  (484, 313) Point two:  (960, 603)
# Coef:  -0.697248540696 Intercept:  644.92271313 intersection_x:  479.371931086
# Point one:  (474, 314) Point two:  (0, 644)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-241-edb838dfd6a6> in <module>()
#       7 clip2 = VideoFileClip('test_videos/solidYellowLeft.mp4')
#       8 yellow_clip = clip2.fl_image(process_image)
# ----> 9 get_ipython().magic('time yellow_clip.write_videofile(yellow_output, audio=False)')
#
# /root/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# /root/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# <decorator-gen-59> in time(self, line, cell, local_ns)
#
# /root/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /root/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1179         if mode=='eval':
#    1180             st = clock2()
# -> 1181             out = eval(code, glob, local_ns)
#    1182             end = clock2()
#    1183         else:
#
# <timed eval> in <module>()
#
# <decorator-gen-172> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params)
#
# /root/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/decorators.py in requires_duration(f, clip, *a, **k)
#      52         raise ValueError("Attribute 'duration' not set")
#      53     else:
# ---> 54         return f(clip, *a, **k)
#      55
#      56
#
# <decorator-gen-171> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params)
#
# /root/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/decorators.py in use_clip_fps_by_default(f, clip, *a, **k)
#     135              for (k,v) in k.items()}
#     136
# --> 137     return f(clip, *new_a, **new_kw)
#
# <decorator-gen-170> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params)
#
# /root/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/decorators.py in convert_masks_to_RGB(f, clip, *a, **k)
#      20     if clip.ismask:
#      21         clip = clip.to_RGB()
# ---> 22     return f(clip, *a, **k)
#      23
#      24 @decorator.decorator
#
# /root/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/video/VideoClip.py in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params)
#     336                            audiofile = audiofile,
#     337                            verbose=verbose, threads=threads,
# --> 338                            ffmpeg_params=ffmpeg_params)
#     339
#     340         if remove_temp and make_audio:
#
# /root/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/video/io/ffmpeg_writer.py in ffmpeg_write_video(clip, filename, fps, codec, bitrate, preset, withmask, write_logfile, audiofile, verbose, threads, ffmpeg_params)
#     214
#     215     for t,frame in clip.iter_frames(progress_bar=True, with_times=True,
# --> 216                                     fps=fps, dtype="uint8"):
#     217         if withmask:
#     218             mask = (255*clip.mask.get_frame(t))
#
# /root/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/tqdm/_tqdm.py in __iter__(self)
#     831 """, fp_write=getattr(self.fp, 'write', sys.stderr.write))
#     832
# --> 833             for obj in iterable:
#     834                 yield obj
#     835                 # Update and print the progressbar.
#
# /root/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/Clip.py in generator()
#     471             for t in np.arange(0, self.duration, 1.0/fps):
#     472
# --> 473                 frame = self.get_frame(t)
#     474
#     475                 if (dtype is not None) and (frame.dtype != dtype):
#
# <decorator-gen-135> in get_frame(self, t)
#
# /root/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/decorators.py in wrapper(f, *a, **kw)
#      87         new_kw = {k: fun(v) if k in varnames else v
#      88                  for (k,v) in kw.items()}
# ---> 89         return f(*new_a, **new_kw)
#      90     return decorator.decorator(wrapper)
#      91
#
# /root/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/Clip.py in get_frame(self, t)
#      93                 return frame
#      94         else:
# ---> 95             return self.make_frame(t)
#      96
#      97     def fl(self, fun, apply_to=[] , keep_duration=True):
#
# /root/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/Clip.py in <lambda>(t)
#     134
#     135         #mf = copy(self.make_frame)
# --> 136         newclip = self.set_make_frame(lambda t: fun(self.get_frame, t))
#     137
#     138         if not keep_duration:
#
# /root/miniconda3/envs/carnd-term1/lib/python3.5/site-packages/moviepy/video/VideoClip.py in <lambda>(gf, t)
#     511         `get_frame(t)` by another frame,  `image_func(get_frame(t))`
#     512         """
# --> 513         return self.fl(lambda gf, t: image_func(gf(t)), apply_to)
#     514
#     515     # --------------------------------------------------------------
#
# <ipython-input-238-64be9686be9f> in process_image(image)
#       3     # TODO: put your pipeline here,
#       4     # you should return the final output (image where lines are drawn on lanes)
# ----> 5     result = draw_lane_lines(image)
#       6     return result
#
# <ipython-input-231-fa30c5b28a15> in draw_lane_lines(image)
#      27     max_line_gap = 100
#      28
# ---> 29     line_image = hough_lines(masked_edges, rho, theta, threshold, min_line_length, max_line_gap)
#      30
#      31     # Draw the lines on the edge image
#
# <ipython-input-229-4ce84488f42e> in hough_lines(img, rho, theta, threshold, min_line_len, max_line_gap)
#     154     lines = cv2.HoughLinesP(img, rho, theta, threshold, np.array([]), minLineLength=min_line_len, maxLineGap=max_line_gap)
#     155     line_img = np.zeros((img.shape[0], img.shape[1], 3), dtype=np.uint8)
# --> 156     draw_lines(line_img, lines)
#     157     return line_img
#     158
#
# <ipython-input-229-4ce84488f42e> in draw_lines(img, lines, color, thickness)
#     136
#     137     # Get intercept and coefficient of fitted lines
# --> 138     left_coefficient, left_intercept = get_line_parameter(left_slope)
#     139     right_coefficient, right_intercept = get_line_parameter(right_slope)
#     140
#
# <ipython-input-229-4ce84488f42e> in get_line_parameter(slope_array)
#      60     if not kept_slopes:
#      61         kept_slopes = slopes
# ---> 62         kept_intercepts = [pair[1] for pair in slope_intercept_array]
#      63     # Take estimate of slope, intercept to be the mean of remaining values
#      64     slope = np.mean(kept_slopes)
#
# NameError: name 'slope_intercept_array' is not defined

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(yellow_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="solidYellowLeft.mp4">
# </video>

# %% [markdown]
# ## Writeup and Submission
#
# If you're satisfied with your video outputs, it's time to make the report writeup in a pdf or markdown file. Once you have this Ipython notebook ready along with the writeup, it's time to submit for review! Here is a [link](https://github.com/udacity/CarND-LaneLines-P1/blob/master/writeup_template.md) to the writeup template file.

# %% [markdown]
# ## Optional Challenge
#
# Try your lane finding pipeline on the video below.  Does it still work?  Can you figure out a way to make it more robust?  If you're up for the challenge, modify your pipeline so it works with this video and submit it along with the rest of your project!

# %%
challenge_output = 'test_videos_output/challenge.mp4'
## To speed up the testing process you may want to try your pipeline on a shorter subclip of the video
## To do so add .subclip(start_second,end_second) to the end of the line below
## Where start_second and end_second are integer values representing the start and end of the subclip
## You may also uncomment the following line for a subclip of the first 5 seconds
##clip3 = VideoFileClip('test_videos/challenge.mp4').subclip(0,5)
clip3 = VideoFileClip('test_videos/challenge.mp4')
challenge_clip = clip2.fl_image(process_image)
# %time challenge_clip.write_videofile(challenge_output, audio=False)

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(challenge_output))
